# %%
# !nvidia-smi
# Out:
# Thu May 14 17:37:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
# !rm -r sample_data

#clone repo multiple-objects-gan
# !git clone https://github.com/tohinz/multiple-objects-gan.git

#!!EDIT THE CHECKPOINT HERE AND IN CONFIG.PY AND IMPORT THE RIGHT DRIVE!!
# !cp '/content/drive/My Drive/coco2Model/checkpoint_0034.pth' '/content/multiple-objects-gan/models/'

#Clone repo COCO-Stack2-GAN
# !git clone https://github.com/ammarnasr/COCO-Stack2-GAN.git

#Move code files coco_s2_train.yml, config.py, utils.py, datasets.py, trainer.py  to their Locations
# !mv /content/COCO-Stack2-GAN/theCode/coco_s2_train.yml /content/multiple-objects-gan/code/coco/stackgan/cfg/
# !mv /content/COCO-Stack2-GAN/theCode/config.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/utils.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/datasets.py    /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/trainer.py    /content/multiple-objects-gan/code/coco/stackgan/

#Remove the Repo
# !rm -r /content/COCO-Stack2-GAN/

#Changing Working dirctory to data
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads data-ms-coco.zip (4.11M) , Extract it , and remove unnesscery files
# !wget https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# !unzip -q data-ms-coco.zip
# !rm data-ms-coco.zip

#Check Working Directory And verify complete download
print(os.getcwd())
print("Check data-ms-coco.zip (4.11M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads coco.zip (1.48G) , Extract it , remove unnesscery files and reorder data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLQXVzOENCY2E3TlU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLQXVzOENCY2E3TlU" -O coco.zip && rm -rf /tmp/cookies.txt
# !unzip -q coco.zip
# !rm -r __MACOSX/
# !rm README.md
# !rm coco.zip
# !mv coco/test/filename.txt MS-COCO/test/
# !mv coco/test/filenames.pickle MS-COCO/test/
# !mv coco/train/char-CNN-RNN-embeddings.pickle MS-COCO/train/
# !mv coco/train/filenames.pickle MS-COCO/train/
# !rm -r coco/

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/MS-COCO/train/')
print(os.getcwd())
print("Check coco.zip (1.48G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads train2014.zip (12.58G) , Extract it , and remove unnesscery files
# !wget http://images.cocodataset.org/zips/train2014.zip
# !unzip -q train2014.zip
# !rm train2014.zip

#Create & Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
os.mkdir('models')
os.chdir('/content/multiple-objects-gan/data/models/')
print(os.getcwd())
print("Check train2014.zip (12.58G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Move pretrained_model.pth (455.37M) to created directory
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU" -O pretrained_model.pth && rm -rf /tmp/cookies.txt

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/')
print(os.getcwd())
print("Check pretrained_model.pth (455.37M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")


#The Command !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am

# %%
# !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Starting training on the MS-COCO data set.
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../../../data/MS-COCO',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMG_DIR': '../../../data/MS-COCO/train/train2014',
#  'IMSIZE': 256,
#  'NET_D': '../../../models/checkpoint_0028.pth',
#  'NET_G': '../../../models/checkpoint_0028.pth',
#  'STAGE': 2,
#  'STAGE1_G': '../../../data/models/pretrained_model.pth',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 20,
#            'MAX_EPOCH': 120,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 2},
#  'USE_BBOX_LAYOUT': True,
#  'USE_LOCAL_PATHWAY': True,
#  'VIS_COUNT': 64,
#  'WORKERS': 16,
#  'Z_DIM': 100}
# Load filenames from: ../../../data/MS-COCO/train/filenames.pickle (82783)
# tcmalloc: large alloc 1695399936 bytes == 0xf82e0000 @  0x7f17c2dee1e7 0x7f17775f75e1 0x7f177765bc78 0x7f177765edb8 0x7f177765f395 0x7f17776f665d 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f17c29ebb97 0x5b250a
# 2020-05-14 18:07:56.228580: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (bbox_net): BBOX_NET(
#       (encode): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=292, out_features=24576, bias=False)
#       (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (label): Sequential(
#       (0): Linear(in_features=209, out_features=128, bias=False)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (local1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (local2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (img): Sequential(
#       (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (label): Sequential(
#     (0): Linear(in_features=209, out_features=128, bias=False)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (local1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(896, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (local2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (encoder): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#   )
#   (hr_joint): Sequential(
#     (0): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(48, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# ---------------------------------------------------------------------------------
# Current Working Directory :  /content/multiple-objects-gan/code/coco/stackgan
# cfg.NET_G :  ../../../models/checkpoint_0028.pth
# ---------------------------------------------------------------------------------
# THIS THE CURRENT DIRECTORY :  /content/multiple-objects-gan/code/coco/stackgan
# Load from:  ../../../models/checkpoint_0028.pth
# Load from:  ../../../models/checkpoint_0028.pth
# STAGE2_D(
#   (local): Sequential(
#     (0): Conv2d(84, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(192, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (act): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv1): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(576, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(768, 1536, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(1536, 3072, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn6): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(3072, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn7): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn8): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
#   (get_uncond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
# )
# 28
# Load Optim and optimizers as :  ../../../models/checkpoint_0028.pth
# epoch :  29  drive_count :  0
# 29
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# epoch     :   29
# count     :   1
#   i       :   0
# Time to i :  16.64460277557373
# D_loss :  0.0057345167733728886
# D_loss_real :  0.00033000222174450755
# D_loss_wrong :  0.0013049469562247396
# D_loss_fake :  0.00745429890230298
# G_loss :  10.893272399902344
# KL_loss :  0.10081213712692261
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   2
#   i       :   500
# Time to i :  625.2186748981476
# D_loss :  0.023309778422117233
# D_loss_real :  0.00032155716326087713
# D_loss_wrong :  0.01274858508259058
# D_loss_fake :  0.028108038008213043
# G_loss :  7.525843620300293
# KL_loss :  0.09009837359189987
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   3
#   i       :   1000
# Time to i :  625.1086480617523
# D_loss :  0.014736134558916092
# D_loss_real :  5.866796709597111e-05
# D_loss_wrong :  0.004629972856491804
# D_loss_fake :  0.019701212644577026
# G_loss :  9.846891403198242
# KL_loss :  0.11834531277418137
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   4
#   i       :   1500
# Time to i :  624.9652585983276
# D_loss :  0.004436923190951347
# D_loss_real :  0.00011422745592426509
# D_loss_wrong :  4.044616434839554e-05
# D_loss_fake :  0.006463820114731789
# G_loss :  10.442371368408203
# KL_loss :  0.10148605704307556
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   5
#   i       :   2000
# Time to i :  624.7185904979706
# D_loss :  0.0026304922066628933
# D_loss_real :  0.0008437726646661758
# D_loss_wrong :  0.0011769174598157406
# D_loss_fake :  0.0020916203502565622
# G_loss :  12.640815734863281
# KL_loss :  0.1359775960445404
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   6
#   i       :   2500
# Time to i :  624.6537237167358
# D_loss :  0.02293693646788597
# D_loss_real :  0.01562526635825634
# D_loss_wrong :  0.000712429522536695
# D_loss_fake :  0.010611290112137794
# G_loss :  5.936984062194824
# KL_loss :  0.08913024514913559
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   29
# count     :   7
#   i       :   3000
# Time to i :  624.6159830093384
# D_loss :  0.01653188467025757
# D_loss_real :  0.01627628691494465
# D_loss_wrong :  4.791187893715687e-05
# D_loss_fake :  0.00035944022238254547
# G_loss :  16.85527992248535
# KL_loss :  0.116074338555336
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [29/120][3448/3449] Loss_D: 0.0366 Loss_G: 9.0235 Loss_KL: 0.0899
#                      Loss_real: 0.0004 Loss_wrong:0.0083 Loss_fake 0.0500
#                      Total Time: 4328.76sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4328.759839296341
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  30  drive_count :  35
# 30
# epoch     :   30
# count     :   8
#   i       :   0
# Time to i :  6.286962509155273
# D_loss :  0.028842488303780556
# D_loss_real :  0.0019256193190813065
# D_loss_wrong :  0.000802250811830163
# D_loss_fake :  0.03997417911887169
# G_loss :  10.099689483642578
# KL_loss :  0.13498125970363617
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   9
#   i       :   500
# Time to i :  626.6641726493835
# D_loss :  0.0982399731874466
# D_loss_real :  0.09571056067943573
# D_loss_wrong :  0.003130295081064105
# D_loss_fake :  0.002228971105068922
# G_loss :  11.325200080871582
# KL_loss :  0.10146127641201019
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   10
#   i       :   1000
# Time to i :  624.505455493927
# D_loss :  0.011409671045839787
# D_loss_real :  0.01135624386370182
# D_loss_wrong :  9.360419426229782e-06
# D_loss_fake :  7.546121196355671e-05
# G_loss :  18.06620216369629
# KL_loss :  0.1372670978307724
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   11
#   i       :   1500
# Time to i :  624.4779677391052
# D_loss :  0.34088465571403503
# D_loss_real :  0.0002392198657616973
# D_loss_wrong :  0.0009154690778814256
# D_loss_fake :  0.5105104446411133
# G_loss :  15.310867309570312
# KL_loss :  0.09597153961658478
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   12
#   i       :   2000
# Time to i :  624.5156083106995
# D_loss :  0.40167349576950073
# D_loss_real :  0.35955023765563965
# D_loss_wrong :  2.2161544620757923e-05
# D_loss_fake :  0.0631738007068634
# G_loss :  3.0343666076660156
# KL_loss :  0.14019525051116943
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   13
#   i       :   2500
# Time to i :  624.3117434978485
# D_loss :  0.07482260465621948
# D_loss_real :  0.044438667595386505
# D_loss_wrong :  0.0004504233947955072
# D_loss_fake :  0.04535070061683655
# G_loss :  7.838994979858398
# KL_loss :  0.10950841754674911
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   30
# count     :   14
#   i       :   3000
# Time to i :  624.4341840744019
# D_loss :  0.634154736995697
# D_loss_real :  0.000722239026799798
# D_loss_wrong :  0.06793410331010818
# D_loss_fake :  0.9161816835403442
# G_loss :  17.18170166015625
# KL_loss :  0.10155224800109863
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [30/120][3448/3449] Loss_D: 0.2358 Loss_G: 14.9086 Loss_KL: 0.1063
#                      Loss_real: 0.0112 Loss_wrong:0.0008 Loss_fake 0.3365
#                      Total Time: 4318.17sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4419.8997168540955
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  31  drive_count :  70
# 31
# epoch     :   31
# count     :   15
#   i       :   0
# Time to i :  6.445034980773926
# D_loss :  0.002545024733990431
# D_loss_real :  0.0003662514500319958
# D_loss_wrong :  0.00018698313215281814
# D_loss_fake :  0.003174668177962303
# G_loss :  15.088631629943848
# KL_loss :  0.12738344073295593
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   16
#   i       :   500
# Time to i :  629.066216468811
# D_loss :  0.011711793951690197
# D_loss_real :  0.00048973155207932
# D_loss_wrong :  0.0004572195466607809
# D_loss_fake :  0.016604483127593994
# G_loss :  9.870601654052734
# KL_loss :  0.10622958838939667
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   17
#   i       :   1000
# Time to i :  624.7684342861176
# D_loss :  0.1367632895708084
# D_loss_real :  0.13410188257694244
# D_loss_wrong :  0.0011786103714257479
# D_loss_fake :  0.003402804024517536
# G_loss :  9.642126083374023
# KL_loss :  0.10088782012462616
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   18
#   i       :   1500
# Time to i :  624.8851776123047
# D_loss :  0.0868329256772995
# D_loss_real :  0.03025805950164795
# D_loss_wrong :  0.0004925767425447702
# D_loss_fake :  0.08461599797010422
# G_loss :  8.697509765625
# KL_loss :  0.12989161908626556
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   19
#   i       :   2000
# Time to i :  624.4924538135529
# D_loss :  0.027019741013646126
# D_loss_real :  0.026264820247888565
# D_loss_wrong :  0.00013335380936041474
# D_loss_fake :  0.0010657038073986769
# G_loss :  14.145566940307617
# KL_loss :  0.11280892789363861
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   20
#   i       :   2500
# Time to i :  624.7292108535767
# D_loss :  0.004309486132115126
# D_loss_real :  0.0011957645183429122
# D_loss_wrong :  0.002594697056338191
# D_loss_fake :  0.0033732338342815638
# G_loss :  13.531529426574707
# KL_loss :  0.0935017317533493
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   31
# count     :   21
#   i       :   3000
# Time to i :  624.2863168716431
# D_loss :  0.01945800520479679
# D_loss_real :  0.019080664962530136
# D_loss_wrong :  0.0010198351228609681
# D_loss_fake :  5.609260551864281e-05
# G_loss :  17.769426345825195
# KL_loss :  0.09318070113658905
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [31/120][3448/3449] Loss_D: 0.0343 Loss_G: 5.4540 Loss_KL: 0.1307
#                      Loss_real: 0.0301 Loss_wrong:0.0002 Loss_fake 0.0062
#                      Total Time: 4321.56sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4321.558046579361
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  32  drive_count :  105
# 32
# epoch     :   32
# count     :   22
#   i       :   0
# Time to i :  6.514659881591797
# D_loss :  0.12306364625692368
# D_loss_real :  3.403771188459359e-05
# D_loss_wrong :  0.0025042651686817408
# D_loss_fake :  0.18329228460788727
# G_loss :  7.702690124511719
# KL_loss :  0.1263781487941742
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   23
#   i       :   500
# Time to i :  626.1609845161438
# D_loss :  0.011866546235978603
# D_loss_real :  0.01054316759109497
# D_loss_wrong :  8.963400614447892e-05
# D_loss_fake :  0.001940251444466412
# G_loss :  14.026183128356934
# KL_loss :  0.10928984731435776
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   24
#   i       :   1000
# Time to i :  624.3518278598785
# D_loss :  0.02732500433921814
# D_loss_real :  0.0003063419717364013
# D_loss_wrong :  0.004728533327579498
# D_loss_fake :  0.03816372528672218
# G_loss :  9.00568675994873
# KL_loss :  0.1264900416135788
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   25
#   i       :   1500
# Time to i :  624.2118363380432
# D_loss :  0.06798873841762543
# D_loss_real :  0.06777060031890869
# D_loss_wrong :  0.00020779175974894315
# D_loss_fake :  0.00022331112995743752
# G_loss :  16.357303619384766
# KL_loss :  0.1360682249069214
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   26
#   i       :   2000
# Time to i :  624.1612219810486
# D_loss :  0.04289122298359871
# D_loss_real :  0.04258476942777634
# D_loss_wrong :  4.027178874821402e-06
# D_loss_fake :  0.00045766751281917095
# G_loss :  14.714709281921387
# KL_loss :  0.1166367158293724
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   27
#   i       :   2500
# Time to i :  624.043609380722
# D_loss :  0.004206868354231119
# D_loss_real :  0.0003983954666182399
# D_loss_wrong :  0.0006035435944795609
# D_loss_fake :  0.005410937592387199
# G_loss :  12.246445655822754
# KL_loss :  0.09485183656215668
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   32
# count     :   28
#   i       :   3000
# Time to i :  624.143515586853
# D_loss :  0.00525923166424036
# D_loss_real :  9.373028296977282e-05
# D_loss_wrong :  8.366688416572288e-05
# D_loss_fake :  0.0077064186334609985
# G_loss :  10.639678955078125
# KL_loss :  0.1312902569770813
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [32/120][3448/3449] Loss_D: 0.0016 Loss_G: 16.9389 Loss_KL: 0.1375
#                      Loss_real: 0.0000 Loss_wrong:0.0035 Loss_fake 0.0006
#                      Total Time: 4316.21sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4416.860107183456
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  33  drive_count :  140
# 33
# epoch     :   33
# count     :   29
#   i       :   0
# Time to i :  6.577472686767578
# D_loss :  0.003788145026192069
# D_loss_real :  0.0011294195428490639
# D_loss_wrong :  2.274240250699222e-05
# D_loss_fake :  0.003976717125624418
# G_loss :  12.743240356445312
# KL_loss :  0.11213608831167221
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   30
#   i       :   500
# Time to i :  628.5984401702881
# D_loss :  0.10126813501119614
# D_loss_real :  6.972636037971824e-05
# D_loss_wrong :  0.002553342143073678
# D_loss_fake :  0.1505209356546402
# G_loss :  7.466487407684326
# KL_loss :  0.11592930555343628
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   31
#   i       :   1000
# Time to i :  625.2850911617279
# D_loss :  0.15412801504135132
# D_loss_real :  0.14567777514457703
# D_loss_wrong :  1.352231265627779e-05
# D_loss_fake :  0.012668605893850327
# G_loss :  8.869885444641113
# KL_loss :  0.11260493844747543
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   32
#   i       :   1500
# Time to i :  624.374443769455
# D_loss :  0.7921637296676636
# D_loss_real :  0.007359052076935768
# D_loss_wrong :  0.0046600415371358395
# D_loss_fake :  1.1748769283294678
# G_loss :  15.673437118530273
# KL_loss :  0.10638903826475143
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   33
#   i       :   2000
# Time to i :  624.4619355201721
# D_loss :  0.2849637269973755
# D_loss_real :  2.027013397309929e-05
# D_loss_wrong :  0.00029363660723902285
# D_loss_fake :  0.427268385887146
# G_loss :  14.7985200881958
# KL_loss :  0.12298551201820374
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   34
#   i       :   2500
# Time to i :  624.2970099449158
# D_loss :  0.006607521791011095
# D_loss_real :  0.006263911724090576
# D_loss_wrong :  0.000599386403337121
# D_loss_fake :  0.00021572178229689598
# G_loss :  18.434616088867188
# KL_loss :  0.14399504661560059
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   33
# count     :   35
#   i       :   3000
# Time to i :  624.2454845905304
# D_loss :  0.011039383709430695
# D_loss_real :  1.976110797841102e-05
# D_loss_wrong :  7.330935477511957e-05
# D_loss_fake :  0.016492780297994614
# G_loss :  8.838443756103516
# KL_loss :  0.1521553248167038
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [33/120][3448/3449] Loss_D: 0.0435 Loss_G: 10.0461 Loss_KL: 0.1369
#                      Loss_real: 0.0013 Loss_wrong:0.0087 Loss_fake 0.0590
#                      Total Time: 4320.17sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4320.174875497818
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  34  drive_count :  175
# 34
# epoch     :   34
# count     :   36
#   i       :   0
# Time to i :  6.1141767501831055
# D_loss :  0.14510706067085266
# D_loss_real :  0.1337554156780243
# D_loss_wrong :  0.000492722843773663
# D_loss_fake :  0.016781114041805267
# G_loss :  7.9192962646484375
# KL_loss :  0.12500768899917603
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   37
#   i       :   500
# Time to i :  626.2824554443359
# D_loss :  0.003856419352814555
# D_loss_real :  0.0017538422252982855
# D_loss_wrong :  2.186660458391998e-05
# D_loss_fake :  0.0031429321970790625
# G_loss :  12.253355026245117
# KL_loss :  0.12005655467510223
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   38
#   i       :   1000
# Time to i :  624.2139501571655
# D_loss :  0.0008191821398213506
# D_loss_real :  0.00016750601935200393
# D_loss_wrong :  0.0003246038977522403
# D_loss_fake :  0.0008152120281010866
# G_loss :  14.665342330932617
# KL_loss :  0.12954172492027283
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   39
#   i       :   1500
# Time to i :  624.3262197971344
# D_loss :  0.6116032004356384
# D_loss_real :  0.001264635706320405
# D_loss_wrong :  0.00212927907705307
# D_loss_fake :  0.9144431352615356
# G_loss :  24.146055221557617
# KL_loss :  0.13038665056228638
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   40
#   i       :   2000
# Time to i :  624.6423687934875
# D_loss :  0.0079521294683218
# D_loss_real :  0.00747604900971055
# D_loss_wrong :  1.9378872821107507e-05
# D_loss_fake :  0.0007044314406812191
# G_loss :  16.593637466430664
# KL_loss :  0.14668142795562744
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   41
#   i       :   2500
# Time to i :  624.917268037796
# D_loss :  0.01412255223840475
# D_loss_real :  0.010952997021377087
# D_loss_wrong :  1.2071031960658729e-05
# D_loss_fake :  0.004748296923935413
# G_loss :  13.305286407470703
# KL_loss :  0.09597627818584442
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   34
# count     :   42
#   i       :   3000
# Time to i :  625.1977527141571
# D_loss :  0.004885293077677488
# D_loss_real :  0.004639941267669201
# D_loss_wrong :  0.0001769461523508653
# D_loss_fake :  0.0002795546024572104
# G_loss :  17.90813446044922
# KL_loss :  0.15237435698509216
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [34/120][3448/3449] Loss_D: 0.0026 Loss_G: 12.8282 Loss_KL: 0.1222
#                      Loss_real: 0.0000 Loss_wrong:0.0001 Loss_fake 0.0038
#                      Total Time: 4319.44sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4420.385967254639
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  35  drive_count :  210
# 35
# epoch     :   35
# count     :   43
#   i       :   0
# Time to i :  6.976558208465576
# D_loss :  0.056663647294044495
# D_loss_real :  0.00022790403454564512
# D_loss_wrong :  0.016705505549907684
# D_loss_fake :  0.07630085945129395
# G_loss :  10.501359939575195
# KL_loss :  0.12056569755077362
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   44
#   i       :   500
# Time to i :  629.6152131557465
# D_loss :  0.004007851239293814
# D_loss_real :  0.003979679197072983
# D_loss_wrong :  8.6243389887386e-06
# D_loss_fake :  3.794614895014092e-05
# G_loss :  23.011987686157227
# KL_loss :  0.1270061582326889
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   45
#   i       :   1000
# Time to i :  626.121687412262
# D_loss :  0.0382961742579937
# D_loss_real :  0.00016755405522417277
# D_loss_wrong :  0.10907956957817078
# D_loss_fake :  0.002653146628290415
# G_loss :  12.691841125488281
# KL_loss :  0.12117616832256317
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   46
#   i       :   1500
# Time to i :  625.1347372531891
# D_loss :  0.021804222837090492
# D_loss_real :  0.0014688821975141764
# D_loss_wrong :  0.005145658738911152
# D_loss_fake :  0.027930181473493576
# G_loss :  8.451345443725586
# KL_loss :  0.11695772409439087
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   47
#   i       :   2000
# Time to i :  625.0169575214386
# D_loss :  0.2929929196834564
# D_loss_real :  0.2928970158100128
# D_loss_wrong :  0.0002694084250833839
# D_loss_fake :  9.154176950687543e-06
# G_loss :  18.017833709716797
# KL_loss :  0.09219411015510559
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   48
#   i       :   2500
# Time to i :  625.0958652496338
# D_loss :  0.05931997299194336
# D_loss_real :  7.970898150233552e-05
# D_loss_wrong :  5.900552059756592e-05
# D_loss_fake :  0.08883088827133179
# G_loss :  7.829448223114014
# KL_loss :  0.1373036503791809
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   35
# count     :   49
#   i       :   3000
# Time to i :  625.0556807518005
# D_loss :  0.031206687912344933
# D_loss_real :  0.03054777905344963
# D_loss_wrong :  0.0018259818898513913
# D_loss_fake :  7.53727144910954e-05
# G_loss :  20.423294067382812
# KL_loss :  0.1177084892988205
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [35/120][3448/3449] Loss_D: 0.0524 Loss_G: 12.3198 Loss_KL: 0.0990
#                      Loss_real: 0.0501 Loss_wrong:0.0002 Loss_fake 0.0033
#                      Total Time: 4326.44sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4326.443618774414
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  36  drive_count :  245
# 36
# epoch     :   36
# count     :   50
#   i       :   0
# Time to i :  6.784412622451782
# D_loss :  0.03267895057797432
# D_loss_real :  0.0006567036616615951
# D_loss_wrong :  0.00011453933984739706
# D_loss_fake :  0.047976091504096985
# G_loss :  9.87260627746582
# KL_loss :  0.12438695132732391
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   36
# count     :   51
#   i       :   500
# Time to i :  627.443745136261
# D_loss :  0.0069047315046191216
# D_loss_real :  0.0002752411237452179
# D_loss_wrong :  0.00022012092813383788
# D_loss_fake :  0.009834174066781998
# G_loss :  10.599736213684082
# KL_loss :  0.10202406346797943
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   36
# count     :   52
#   i       :   1000
# Time to i :  624.8927960395813
# D_loss :  0.07921411097049713
# D_loss_real :  0.07702288031578064
# D_loss_wrong :  0.0005218187579885125
# D_loss_fake :  0.003025934100151062
# G_loss :  13.053596496582031
# KL_loss :  0.12278121709823608
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   36
# count     :   53
#   i       :   1500
# Time to i :  625.0628890991211
# D_loss :  0.045990362763404846
# D_loss_real :  0.045583128929138184
# D_loss_wrong :  0.0011955304071307182
# D_loss_fake :  1.3087133083899971e-05
# G_loss :  27.115360260009766
# KL_loss :  0.13745272159576416
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   36
# count     :   54
#   i       :   2000
# Time to i :  624.8606879711151
# D_loss :  0.008662045001983643
# D_loss_real :  0.002299961168318987
# D_loss_wrong :  0.01746430993080139
# D_loss_fake :  0.0008109697373583913
# G_loss :  14.772924423217773
# KL_loss :  0.11036670207977295
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   36
# count     :   55
#   i       :   2500
# Time to i :  625.0710003376007
# D_loss :  0.0007881164201535285
# D_loss_real :  0.0005429788143374026
# D_loss_wrong :  2.255557592434343e-05
# D_loss_fake :  0.0003564286162145436
# G_loss :  16.22547149658203
# KL_loss :  0.11644594371318817
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
