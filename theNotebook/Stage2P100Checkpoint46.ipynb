# %%
# !nvidia-smi
# Out:
# Thu Jun 11 03:23:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
# !rm -r sample_data

#clone repo multiple-objects-gan
# !git clone https://github.com/tohinz/multiple-objects-gan.git

#!!EDIT THE CHECKPOINT HERE AND IN CONFIG.PY AND IMPORT THE RIGHT DRIVE!!
# !cp '/content/drive/My Drive/coco2Model/checkpoint_0046.pth' '/content/multiple-objects-gan/models/'

#Clone repo COCO-Stack2-GAN
# !git clone https://github.com/ammarnasr/COCO-Stack2-GAN.git

#Move code files coco_s2_train.yml, config.py, utils.py, datasets.py, trainer.py  to their Locations
# !mv /content/COCO-Stack2-GAN/theCode/coco_s2_train.yml /content/multiple-objects-gan/code/coco/stackgan/cfg/
# !mv /content/COCO-Stack2-GAN/theCode/config.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/utils.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/datasets.py    /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/trainer.py    /content/multiple-objects-gan/code/coco/stackgan/

#Remove the Repo
# !rm -r /content/COCO-Stack2-GAN/

#Changing Working dirctory to data
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads data-ms-coco.zip (4.11M) , Extract it , and remove unnesscery files
# !wget https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# !unzip -q data-ms-coco.zip
# !rm data-ms-coco.zip

#Check Working Directory And verify complete download
print(os.getcwd())
print("Check data-ms-coco.zip (4.11M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads coco.zip (1.48G) , Extract it , remove unnesscery files and reorder data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLQXVzOENCY2E3TlU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLQXVzOENCY2E3TlU" -O coco.zip && rm -rf /tmp/cookies.txt
# !unzip -q coco.zip
# !rm -r __MACOSX/
# !rm README.md
# !rm coco.zip
# !mv coco/test/filename.txt MS-COCO/test/
# !mv coco/test/filenames.pickle MS-COCO/test/
# !mv coco/train/char-CNN-RNN-embeddings.pickle MS-COCO/train/
# !mv coco/train/filenames.pickle MS-COCO/train/
# !rm -r coco/

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/MS-COCO/train/')
print(os.getcwd())
print("Check coco.zip (1.48G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads train2014.zip (12.58G) , Extract it , and remove unnesscery files
# !wget http://images.cocodataset.org/zips/train2014.zip
# !unzip -q train2014.zip
# !rm train2014.zip

#Create & Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
os.mkdir('models')
os.chdir('/content/multiple-objects-gan/data/models/')
print(os.getcwd())
print("Check train2014.zip (12.58G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Move pretrained_model.pth (455.37M) to created directory
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU" -O pretrained_model.pth && rm -rf /tmp/cookies.txt

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/')
print(os.getcwd())
print("Check pretrained_model.pth (455.37M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")


#The Command !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Cloning into 'multiple-objects-gan'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 415 (delta 4), reused 0 (delta 0), pack-reused 398
# Receiving objects: 100% (415/415), 23.04 MiB | 7.87 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Cloning into 'COCO-Stack2-GAN'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 182 (delta 92), reused 133 (delta 48), pack-reused 0
# Receiving objects: 100% (182/182), 1.55 MiB | 895.00 KiB/s, done.
# Resolving deltas: 100% (92/92), done.
# /content/multiple-objects-gan/data
# Check Marker in first Comment of every file for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-06-11 03:25:51--  https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# Resolving www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)... 134.100.9.79
# Connecting to www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)|134.100.9.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4312414 (4.1M) [application/zip]
# Saving to: ‘data-ms-coco.zip’
#
# data-ms-coco.zip    100%[===================>]   4.11M  1.67MB/s    in 2.5s
#
# 2020-06-11 03:25:55 (1.67 MB/s) - ‘data-ms-coco.zip’ saved [4312414/4312414]
#
# /content/multiple-objects-gan/data
# Check data-ms-coco.zip (4.11M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-06-11 03:26:03--  https://docs.google.com/uc?export=download&confirm=NxNm&id=0B3y_msrWZaXLQXVzOENCY2E3TlU
# Resolving docs.google.com (docs.google.com)... 74.125.68.100, 74.125.68.102, 74.125.68.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.68.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download [following]
# --2020-06-11 03:26:03--  https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download
# Resolving doc-0k-6c-docs.googleusercontent.com (doc-0k-6c-docs.googleusercontent.com)... 172.217.194.132, 2404:6800:4003:c04::84
# Connecting to doc-0k-6c-docs.googleusercontent.com (doc-0k-6c-docs.googleusercontent.com)|172.217.194.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=l012fdt6np7ku&continue=https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=c30kaj3v2fc4mrmgaiqch24cg357jdt7 [following]
# --2020-06-11 03:26:03--  https://docs.google.com/nonceSigner?nonce=l012fdt6np7ku&continue=https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=c30kaj3v2fc4mrmgaiqch24cg357jdt7
# Connecting to docs.google.com (docs.google.com)|74.125.68.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=l012fdt6np7ku&user=13877021167380223285Z&hash=ag2i31p5fo57aou1jmkupc1arar2f2l1 [following]
# --2020-06-11 03:26:04--  https://doc-0k-6c-docs.googleusercontent.com/docs/securesc/5i68e56i7jefv0srubgfu5gtnualunat/21vtq8hv7gba1vlceilk4kas0m4jaqrb/1591845900000/16427414401649018968/13877021167380223285Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=l012fdt6np7ku&user=13877021167380223285Z&hash=ag2i31p5fo57aou1jmkupc1arar2f2l1
# Connecting to doc-0k-6c-docs.googleusercontent.com (doc-0k-6c-docs.googleusercontent.com)|172.217.194.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘coco.zip’
#
# coco.zip                [              <=>   ]   1.48G  71.4MB/s    in 39s
#
# 2020-06-11 03:26:43 (38.8 MB/s) - ‘coco.zip’ saved [1587844671]
#
# /content/multiple-objects-gan/data/MS-COCO/train
# Check coco.zip (1.48G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-06-11 03:27:24--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.14.140
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.14.140|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  14.1MB/s    in 15m 46s
#
# 2020-06-11 03:43:11 (13.6 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# /content/multiple-objects-gan/data
# /content/multiple-objects-gan/data/models
# Check train2014.zip (12.58G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-06-11 03:49:40--  https://docs.google.com/uc?export=download&confirm=s5iG&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU
# Resolving docs.google.com (docs.google.com)... 74.125.24.113, 74.125.24.100, 74.125.24.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download [following]
# --2020-06-11 03:49:40--  https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download
# Resolving doc-04-6g-docs.googleusercontent.com (doc-04-6g-docs.googleusercontent.com)... 172.217.194.132, 2404:6800:4003:c04::84
# Connecting to doc-04-6g-docs.googleusercontent.com (doc-04-6g-docs.googleusercontent.com)|172.217.194.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=dr281mmhhjjsi&continue=https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=rgutu3sep2lm0n1rigc98jq27lt8v5cs [following]
# --2020-06-11 03:49:41--  https://docs.google.com/nonceSigner?nonce=dr281mmhhjjsi&continue=https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=rgutu3sep2lm0n1rigc98jq27lt8v5cs
# Connecting to docs.google.com (docs.google.com)|74.125.24.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=dr281mmhhjjsi&user=05309138490573588742Z&hash=c7qngpi7g2l2is37qss8lj2gvnac3i91 [following]
# --2020-06-11 03:49:41--  https://doc-04-6g-docs.googleusercontent.com/docs/securesc/jn4qotmjm2fdpn2b1nvrcbjkf876q44o/h7qujnutevucpq3g6r6huughf2g9m82n/1591847325000/06568122908834480149/05309138490573588742Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=dr281mmhhjjsi&user=05309138490573588742Z&hash=c7qngpi7g2l2is37qss8lj2gvnac3i91
# Connecting to doc-04-6g-docs.googleusercontent.com (doc-04-6g-docs.googleusercontent.com)|172.217.194.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘pretrained_model.pth’
#
# pretrained_model.pt     [      <=>           ] 455.37M  51.2MB/s    in 9.3s
#
# 2020-06-11 03:49:51 (49.2 MB/s) - ‘pretrained_model.pth’ saved [477486037]
#
# /content/multiple-objects-gan
# Check pretrained_model.pth (455.37M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------

# %%
# !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Starting training on the MS-COCO data set.
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../../../data/MS-COCO',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMG_DIR': '../../../data/MS-COCO/train/train2014',
#  'IMSIZE': 256,
#  'NET_D': '../../../models/checkpoint_0044.pth',
#  'NET_G': '../../../models/checkpoint_0044.pth',
#  'STAGE': 2,
#  'STAGE1_G': '../../../data/models/pretrained_model.pth',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 20,
#            'MAX_EPOCH': 120,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 2},
#  'USE_BBOX_LAYOUT': True,
#  'USE_LOCAL_PATHWAY': True,
#  'VIS_COUNT': 64,
#  'WORKERS': 16,
#  'Z_DIM': 100}
# Load filenames from: ../../../data/MS-COCO/train/filenames.pickle (82783)
# tcmalloc: large alloc 1695399936 bytes == 0xf934e000 @  0x7f4cbab791e7 0x7f4c6f3825e1 0x7f4c6f3e6c78 0x7f4c6f3e9db8 0x7f4c6f3ea395 0x7f4c6f48165d 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f4cba776b97 0x5b250a
# 2020-06-11 03:50:53.191392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (bbox_net): BBOX_NET(
#       (encode): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=292, out_features=24576, bias=False)
#       (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (label): Sequential(
#       (0): Linear(in_features=209, out_features=128, bias=False)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (local1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (local2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (img): Sequential(
#       (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (label): Sequential(
#     (0): Linear(in_features=209, out_features=128, bias=False)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (local1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(896, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (local2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (encoder): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#   )
#   (hr_joint): Sequential(
#     (0): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(48, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# ---------------------------------------------------------------------------------
# Current Working Directory :  /content/multiple-objects-gan/code/coco/stackgan
# cfg.NET_G :  ../../../models/checkpoint_0044.pth
# ---------------------------------------------------------------------------------
# THIS THE CURRENT DIRECTORY :  /content/multiple-objects-gan/code/coco/stackgan
# Load from:  ../../../models/checkpoint_0044.pth
# Load from:  ../../../models/checkpoint_0044.pth
# STAGE2_D(
#   (local): Sequential(
#     (0): Conv2d(84, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(192, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (act): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv1): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(576, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(768, 1536, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(1536, 3072, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn6): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(3072, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn7): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn8): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
#   (get_uncond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
# )
# 44
# Load Optim and optimizers as :  ../../../models/checkpoint_0044.pth
# epoch :  45  drive_count :  0
# 45
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# epoch     :   45
# count     :   1
#   i       :   0
# Time to i :  20.63831615447998
# D_loss :  0.028015004470944405
# D_loss_real :  0.026992090046405792
# D_loss_wrong :  0.0028046939987689257
# D_loss_fake :  0.00013202495756559074
# G_loss :  17.632946014404297
# KL_loss :  0.10164810717105865
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   2
#   i       :   500
# Time to i :  1347.8673174381256
# D_loss :  0.014012875035405159
# D_loss_real :  0.00326552614569664
# D_loss_wrong :  7.156006176955998e-05
# D_loss_fake :  0.016085242852568626
# G_loss :  4.561651229858398
# KL_loss :  0.12689918279647827
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   3
#   i       :   1000
# Time to i :  1351.4495487213135
# D_loss :  0.0023955528158694506
# D_loss_real :  0.0003278723743278533
# D_loss_wrong :  0.0017077024094760418
# D_loss_fake :  0.0022476695012301207
# G_loss :  13.68082046508789
# KL_loss :  0.09774087369441986
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   4
#   i       :   1500
# Time to i :  1351.2327029705048
# D_loss :  2.960724115371704
# D_loss_real :  2.9605255126953125
# D_loss_wrong :  2.4204609871958382e-06
# D_loss_fake :  0.00029666570480912924
# G_loss :  1.5416061878204346
# KL_loss :  0.12421431392431259
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   5
#   i       :   2000
# Time to i :  1351.0661232471466
# D_loss :  0.01296011358499527
# D_loss_real :  0.012432755902409554
# D_loss_wrong :  5.498396058101207e-05
# D_loss_fake :  0.0007635450456291437
# G_loss :  19.426902770996094
# KL_loss :  0.13107459247112274
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   6
#   i       :   2500
# Time to i :  1350.1648812294006
# D_loss :  0.6492260694503784
# D_loss_real :  6.528470839839429e-05
# D_loss_wrong :  0.003892769105732441
# D_loss_fake :  0.9717947840690613
# G_loss :  26.66814422607422
# KL_loss :  0.12269037961959839
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   45
# count     :   7
#   i       :   3000
# Time to i :  1349.2229375839233
# D_loss :  0.5972468256950378
# D_loss_real :  0.5951440334320068
# D_loss_wrong :  6.115948849583219e-07
# D_loss_fake :  0.0031539180781692266
# G_loss :  1.6749093532562256
# KL_loss :  0.10630057752132416
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [45/120][3448/3449] Loss_D: 0.0007 Loss_G: 18.0415 Loss_KL: 0.1115
#                      Loss_real: 0.0002 Loss_wrong:0.0000 Loss_fake 0.0007
#                      Total Time: 9334.38sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  9334.379009485245
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  46  drive_count :  35
# 46
# epoch     :   46
# count     :   8
#   i       :   0
# Time to i :  8.11929202079773
# D_loss :  0.0036869875621050596
# D_loss_real :  5.536741082323715e-05
# D_loss_wrong :  3.550185647327453e-05
# D_loss_fake :  0.005429679527878761
# G_loss :  12.292890548706055
# KL_loss :  0.1380593478679657
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   9
#   i       :   500
# Time to i :  1356.282256603241
# D_loss :  0.02537318505346775
# D_loss_real :  0.0007699091220274568
# D_loss_wrong :  0.0027092767413705587
# D_loss_fake :  0.03555027395486832
# G_loss :  10.966523170471191
# KL_loss :  0.12518993020057678
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   10
#   i       :   1000
# Time to i :  1349.6534929275513
# D_loss :  0.009913269430398941
# D_loss_real :  0.009844174608588219
# D_loss_wrong :  7.362593896687031e-05
# D_loss_fake :  6.68292268528603e-05
# G_loss :  21.16106414794922
# KL_loss :  0.11680909246206284
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   11
#   i       :   1500
# Time to i :  1349.9174296855927
# D_loss :  0.0009662213851697743
# D_loss_real :  2.3270604287972674e-06
# D_loss_wrong :  0.00010255961387883872
# D_loss_fake :  0.001394561491906643
# G_loss :  15.867300987243652
# KL_loss :  0.10709860175848007
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   12
#   i       :   2000
# Time to i :  1350.5125529766083
# D_loss :  0.05520283430814743
# D_loss_real :  0.05138470605015755
# D_loss_wrong :  3.573561480152421e-05
# D_loss_fake :  0.005709324963390827
# G_loss :  10.056840896606445
# KL_loss :  0.11258289217948914
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   13
#   i       :   2500
# Time to i :  1349.8103032112122
# D_loss :  0.4477868676185608
# D_loss_real :  0.0010914829326793551
# D_loss_wrong :  0.00019958775374107063
# D_loss_fake :  0.6699432134628296
# G_loss :  11.849207878112793
# KL_loss :  0.12345682084560394
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   46
# count     :   14
#   i       :   3000
# Time to i :  1350.042561531067
# D_loss :  1.27055025100708
# D_loss_real :  1.270402193069458
# D_loss_wrong :  7.546979031758383e-05
# D_loss_fake :  0.0001843413629103452
# G_loss :  3.2376813888549805
# KL_loss :  0.1251743733882904
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [46/120][3448/3449] Loss_D: 0.1206 Loss_G: 10.2333 Loss_KL: 0.1203
#                      Loss_real: 0.0002 Loss_wrong:0.0000 Loss_fake 0.1806
#                      Total Time: 9327.15sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  9426.904338359833
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  47  drive_count :  70
# 47
# epoch     :   47
# count     :   15
#   i       :   0
# Time to i :  8.062865734100342
# D_loss :  0.04271494224667549
# D_loss_real :  0.00017274577112402767
# D_loss_wrong :  0.000670585606712848
# D_loss_fake :  0.0634780004620552
# G_loss :  10.328862190246582
# KL_loss :  0.12184115499258041
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
