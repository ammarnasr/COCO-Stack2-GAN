# %%
# !nvidia-smi
# Out:
# Mon May 11 00:09:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
#!rm -r sample_data

#clone repo multiple-objects-gan
# !git clone https://github.com/tohinz/multiple-objects-gan.git

#!!EDIT THE CHECKPOINT HERE AND IN CONFIG.PY AND IMPORT THE RIGHT DRIVE!!
# !cp '/content/drive/My Drive/coco2Model/checkpoint_0020.pth' '/content/multiple-objects-gan/models/'

#Clone repo COCO-Stack2-GAN
# !git clone https://github.com/ammarnasr/COCO-Stack2-GAN.git

#Move code files coco_s2_train.yml, config.py, utils.py, datasets.py, trainer.py  to their Locations
# !mv /content/COCO-Stack2-GAN/theCode/coco_s2_train.yml /content/multiple-objects-gan/code/coco/stackgan/cfg/
# !mv /content/COCO-Stack2-GAN/theCode/config.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/utils.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/datasets.py    /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/trainer.py    /content/multiple-objects-gan/code/coco/stackgan/

#Remove the Repo
# !rm -r /content/COCO-Stack2-GAN/

#Changing Working dirctory to data
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads data-ms-coco.zip (4.11M) , Extract it , and remove unnesscery files
# !wget https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# !unzip -q data-ms-coco.zip
# !rm data-ms-coco.zip

#Check Working Directory And verify complete download
print(os.getcwd())
print("Check data-ms-coco.zip (4.11M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads coco.zip (1.48G) , Extract it , remove unnesscery files and reorder data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLQXVzOENCY2E3TlU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLQXVzOENCY2E3TlU" -O coco.zip && rm -rf /tmp/cookies.txt
# !unzip -q coco.zip
# !rm -r __MACOSX/
# !rm README.md
# !rm coco.zip
# !mv coco/test/filename.txt MS-COCO/test/
# !mv coco/test/filenames.pickle MS-COCO/test/
# !mv coco/train/char-CNN-RNN-embeddings.pickle MS-COCO/train/
# !mv coco/train/filenames.pickle MS-COCO/train/
# !rm -r coco/

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/MS-COCO/train/')
print(os.getcwd())
print("Check coco.zip (1.48G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads train2014.zip (12.58G) , Extract it , and remove unnesscery files
# !wget http://images.cocodataset.org/zips/train2014.zip
# !unzip -q train2014.zip
# !rm train2014.zip

#Create & Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
os.mkdir('models')
os.chdir('/content/multiple-objects-gan/data/models/')
print(os.getcwd())
print("Check train2014.zip (12.58G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Move pretrained_model.pth (455.37M) to created directory
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU" -O pretrained_model.pth && rm -rf /tmp/cookies.txt

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/')
print(os.getcwd())
print("Check pretrained_model.pth (455.37M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")


#The Command !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Cloning into 'multiple-objects-gan'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 415 (delta 4), reused 0 (delta 0), pack-reused 398
# Receiving objects: 100% (415/415), 23.04 MiB | 20.30 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Cloning into 'COCO-Stack2-GAN'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 130 (delta 65), reused 93 (delta 33), pack-reused 0
# Receiving objects: 100% (130/130), 1.48 MiB | 3.34 MiB/s, done.
# Resolving deltas: 100% (65/65), done.
# /content/multiple-objects-gan/data
# Check Marker in first Comment of every file for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-07 07:48:35--  https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# Resolving www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)... 134.100.9.79
# Connecting to www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)|134.100.9.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4312414 (4.1M) [application/zip]
# Saving to: ‘data-ms-coco.zip’
#
# data-ms-coco.zip    100%[===================>]   4.11M  --.-KB/s    in 0.1s
#
# 2020-05-07 07:48:35 (31.3 MB/s) - ‘data-ms-coco.zip’ saved [4312414/4312414]
#
# /content/multiple-objects-gan/data
# Check data-ms-coco.zip (4.11M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-07 07:48:45--  https://docs.google.com/uc?export=download&confirm=N02U&id=0B3y_msrWZaXLQXVzOENCY2E3TlU
# Resolving docs.google.com (docs.google.com)... 74.125.140.101, 74.125.140.138, 74.125.140.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.140.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download [following]
# --2020-05-07 07:48:45--  https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download
# Resolving doc-0g-5s-docs.googleusercontent.com (doc-0g-5s-docs.googleusercontent.com)... 74.125.140.132, 2a00:1450:400c:c08::84
# Connecting to doc-0g-5s-docs.googleusercontent.com (doc-0g-5s-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=0hlgpmeo9o6fa&continue=https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=sept0g7bqcd64kk9fev96a78ip80bka8 [following]
# --2020-05-07 07:48:45--  https://docs.google.com/nonceSigner?nonce=0hlgpmeo9o6fa&continue=https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=sept0g7bqcd64kk9fev96a78ip80bka8
# Connecting to docs.google.com (docs.google.com)|74.125.140.101|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=0hlgpmeo9o6fa&user=03371851843478370073Z&hash=766nk30c70o35g8gs1q5l3gmj69g5dd4 [following]
# --2020-05-07 07:48:45--  https://doc-0g-5s-docs.googleusercontent.com/docs/securesc/gets8me73178f8um697bgq4buatiqo5u/n0chon2fp7q49rui3oecc4tlv7oh9r1g/1588837725000/16427414401649018968/03371851843478370073Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=0hlgpmeo9o6fa&user=03371851843478370073Z&hash=766nk30c70o35g8gs1q5l3gmj69g5dd4
# Connecting to doc-0g-5s-docs.googleusercontent.com (doc-0g-5s-docs.googleusercontent.com)|74.125.140.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘coco.zip’
#
# coco.zip                [        <=>         ]   1.48G  66.8MB/s    in 15s
#
# 2020-05-07 07:49:01 (101 MB/s) - ‘coco.zip’ saved [1587844671]
#
# /content/multiple-objects-gan/data/MS-COCO/train
# Check coco.zip (1.48G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-07 07:50:04--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.4.12
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.4.12|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  36.2MB/s    in 6m 1s
#
# 2020-05-07 07:56:06 (35.7 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# /content/multiple-objects-gan/data
# /content/multiple-objects-gan/data/models
# Check train2014.zip (12.58G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-07 08:02:34--  https://docs.google.com/uc?export=download&confirm=Egb&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU
# Resolving docs.google.com (docs.google.com)... 74.125.140.101, 74.125.140.113, 74.125.140.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.140.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pretrained_model.pth’
#
# pretrained_model.pt     [ <=>                ]   3.20K  --.-KB/s    in 0s
#
# 2020-05-07 08:02:34 (50.9 MB/s) - ‘pretrained_model.pth’ saved [3279]
#
# /content/multiple-objects-gan
# Check pretrained_model.pth (455.37M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Starting training on the MS-COCO data set.
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../../../data/MS-COCO',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMG_DIR': '../../../data/MS-COCO/train/train2014',
#  'IMSIZE': 256,
#  'NET_D': '../../../models/checkpoint_0014.pth',
#  'NET_G': '../../../models/checkpoint_0014.pth',
#  'STAGE': 2,
#  'STAGE1_G': '../../../data/models/pretrained_model.pth',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 20,
#            'MAX_EPOCH': 120,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 2},
#  'USE_BBOX_LAYOUT': True,
#  'USE_LOCAL_PATHWAY': True,
#  'VIS_COUNT': 64,
#  'WORKERS': 16,
#  'Z_DIM': 100}
# Load filenames from: ../../../data/MS-COCO/train/filenames.pickle (82783)
# tcmalloc: large alloc 1695399936 bytes == 0xf845a000 @  0x7f9e9978f1e7 0x7f9e4df9a5e1 0x7f9e4dffd138 0x7f9e4e000278 0x7f9e4e000855 0x7f9e4e097b1d 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f9e9938cb97 0x5b250a
# 2020-05-07 08:04:52.732340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (bbox_net): BBOX_NET(
#       (encode): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=292, out_features=24576, bias=False)
#       (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (label): Sequential(
#       (0): Linear(in_features=209, out_features=128, bias=False)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (local1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (local2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (img): Sequential(
#       (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (label): Sequential(
#     (0): Linear(in_features=209, out_features=128, bias=False)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (local1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(896, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (local2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (encoder): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#   )
#   (hr_joint): Sequential(
#     (0): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(48, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# ---------------------------------------------------------------------------------
# Current Working Directory :  /content/multiple-objects-gan/code/coco/stackgan
# cfg.NET_G :  ../../../models/checkpoint_0014.pth
# ---------------------------------------------------------------------------------
# THIS THE CURRENT DIRECTORY :  /content/multiple-objects-gan/code/coco/stackgan
# Load from:  ../../../models/checkpoint_0014.pth
# Load from:  ../../../models/checkpoint_0014.pth
# STAGE2_D(
#   (local): Sequential(
#     (0): Conv2d(84, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(192, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (act): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv1): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(576, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(768, 1536, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(1536, 3072, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn6): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(3072, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn7): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn8): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
#   (get_uncond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
# )
# 14
# Load Optim and optimizers as :  ../../../models/checkpoint_0014.pth
# epoch :  15  drive_count :  0
# 15
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# epoch     :   15
# count     :   1
#   i       :   0
# Time to i :  17.309966564178467
# D_loss :  0.2035433053970337
# D_loss_real :  0.003770147217437625
# D_loss_wrong :  0.022450294345617294
# D_loss_fake :  0.28843456506729126
# G_loss :  13.822233200073242
# KL_loss :  0.08048324286937714
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   2
#   i       :   500
# Time to i :  626.5744285583496
# D_loss :  0.023777948692440987
# D_loss_real :  0.001313651679083705
# D_loss_wrong :  0.0033996899146586657
# D_loss_fake :  0.031996600329875946
# G_loss :  6.843936443328857
# KL_loss :  0.08927425742149353
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   3
#   i       :   1000
# Time to i :  625.2429823875427
# D_loss :  0.07370367646217346
# D_loss_real :  0.0278039388358593
# D_loss_wrong :  0.014779143035411835
# D_loss_fake :  0.061460040509700775
# G_loss :  8.698009490966797
# KL_loss :  0.11265642940998077
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   4
#   i       :   1500
# Time to i :  625.0983352661133
# D_loss :  0.27085253596305847
# D_loss_real :  0.2548868954181671
# D_loss_wrong :  0.0004059821367263794
# D_loss_fake :  0.023745456710457802
# G_loss :  4.467726230621338
# KL_loss :  0.10805772244930267
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   5
#   i       :   2000
# Time to i :  625.0854465961456
# D_loss :  0.2937251329421997
# D_loss_real :  0.2468084841966629
# D_loss_wrong :  0.0005184134934097528
# D_loss_fake :  0.07011575996875763
# G_loss :  5.572878360748291
# KL_loss :  0.09786873310804367
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   6
#   i       :   2500
# Time to i :  624.7357790470123
# D_loss :  0.0836806446313858
# D_loss_real :  0.019293632358312607
# D_loss_wrong :  0.16538006067276
# D_loss_fake :  0.013890484347939491
# G_loss :  11.688321113586426
# KL_loss :  0.10603997111320496
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   7
#   i       :   3000
# Time to i :  624.4788064956665
# D_loss :  0.03108605183660984
# D_loss_real :  0.01599736139178276
# D_loss_wrong :  0.002008731011301279
# D_loss_fake :  0.021628670394420624
# G_loss :  11.98663330078125
# KL_loss :  0.0973707064986229
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [15/120][3448/3449] Loss_D: 0.2464 Loss_G: 9.8634 Loss_KL: 0.0810
#                      Loss_real: 0.2453 Loss_wrong:0.0007 Loss_fake 0.0013
#                      Total Time: 4331.96sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4331.963141202927
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  16  drive_count :  35
# 16
# epoch     :   16
# count     :   8
#   i       :   0
# Time to i :  7.8427815437316895
# D_loss :  0.08879368007183075
# D_loss_real :  0.025683537125587463
# D_loss_wrong :  0.00035686796763911843
# D_loss_fake :  0.0944867879152298
# G_loss :  6.580595016479492
# KL_loss :  0.07800416648387909
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   9
#   i       :   500
# Time to i :  628.4469118118286
# D_loss :  0.2228643298149109
# D_loss_real :  0.00488396268337965
# D_loss_wrong :  0.0007416913285851479
# D_loss_fake :  0.32659968733787537
# G_loss :  10.341757774353027
# KL_loss :  0.0895095095038414
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   10
#   i       :   1000
# Time to i :  624.4055082798004
# D_loss :  0.14685188233852386
# D_loss_real :  0.14627772569656372
# D_loss_wrong :  0.00014608139463234693
# D_loss_fake :  0.000788190693128854
# G_loss :  13.636067390441895
# KL_loss :  0.07487224042415619
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   11
#   i       :   1500
# Time to i :  624.4404072761536
# D_loss :  1.8096153736114502
# D_loss_real :  0.0009605417726561427
# D_loss_wrong :  0.350410133600235
# D_loss_fake :  2.5377771854400635
# G_loss :  12.438672065734863
# KL_loss :  0.0956326350569725
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   12
#   i       :   2000
# Time to i :  624.3434519767761
# D_loss :  0.0886286273598671
# D_loss_real :  0.08579473197460175
# D_loss_wrong :  0.00016769017383921891
# D_loss_fake :  0.0041669998317956924
# G_loss :  10.06924819946289
# KL_loss :  0.07618559896945953
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   13
#   i       :   2500
# Time to i :  624.322573184967
# D_loss :  0.5991159677505493
# D_loss_real :  0.3424912393093109
# D_loss_wrong :  0.0008603621972724795
# D_loss_fake :  0.3845069706439972
# G_loss :  8.841636657714844
# KL_loss :  0.09784548729658127
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   16
# count     :   14
#   i       :   3000
# Time to i :  624.3887407779694
# D_loss :  0.040341198444366455
# D_loss_real :  0.03728720545768738
# D_loss_wrong :  0.007470516487956047
# D_loss_fake :  0.0008457292569801211
# G_loss :  16.520673751831055
# KL_loss :  0.08628828823566437
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [16/120][3448/3449] Loss_D: 0.0136 Loss_G: 11.2100 Loss_KL: 0.1102
#                      Loss_real: 0.0064 Loss_wrong:0.0002 Loss_fake 0.0108
#                      Total Time: 4321.12sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4422.413371086121
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  17  drive_count :  70
# 17
# epoch     :   17
# count     :   15
#   i       :   0
# Time to i :  7.930098056793213
# D_loss :  0.15832391381263733
# D_loss_real :  0.08158610016107559
# D_loss_wrong :  0.07362884283065796
# D_loss_fake :  0.07829231023788452
# G_loss :  7.845399856567383
# KL_loss :  0.07429354637861252
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   16
#   i       :   500
# Time to i :  629.3455250263214
# D_loss :  0.12220136821269989
# D_loss_real :  0.07596410065889359
# D_loss_wrong :  0.0036193127743899822
# D_loss_fake :  0.06754624098539352
# G_loss :  4.979112148284912
# KL_loss :  0.08729812502861023
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   17
#   i       :   1000
# Time to i :  624.3847031593323
# D_loss :  0.6268685460090637
# D_loss_real :  0.625409722328186
# D_loss_wrong :  0.0007039260235615075
# D_loss_fake :  0.0018362782429903746
# G_loss :  5.534867763519287
# KL_loss :  0.06299391388893127
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   18
#   i       :   1500
# Time to i :  624.1319704055786
# D_loss :  0.14921946823596954
# D_loss_real :  0.008596483618021011
# D_loss_wrong :  0.026018043980002403
# D_loss_fake :  0.19792544841766357
# G_loss :  8.538597106933594
# KL_loss :  0.10405191034078598
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   19
#   i       :   2000
# Time to i :  624.3182713985443
# D_loss :  0.3755829930305481
# D_loss_real :  0.014709196984767914
# D_loss_wrong :  0.0006532137049362063
# D_loss_fake :  0.540984034538269
# G_loss :  20.07811737060547
# KL_loss :  0.0902223214507103
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   20
#   i       :   2500
# Time to i :  624.204847574234
# D_loss :  0.9892303347587585
# D_loss_real :  0.0002764977980405092
# D_loss_wrong :  0.008254478685557842
# D_loss_fake :  1.4793035984039307
# G_loss :  5.144074440002441
# KL_loss :  0.11179470270872116
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   17
# count     :   21
#   i       :   3000
# Time to i :  624.3837866783142
# D_loss :  0.18413126468658447
# D_loss_real :  0.0004355873679742217
# D_loss_wrong :  0.0031296040397137403
# D_loss_fake :  0.27397871017456055
# G_loss :  12.198563575744629
# KL_loss :  0.0965515673160553
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [17/120][3448/3449] Loss_D: 1.8914 Loss_G: 11.0522 Loss_KL: 0.1046
#                      Loss_real: 0.0003 Loss_wrong:0.1149 Loss_fake 2.7791
#                      Total Time: 4321.48sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4321.4803857803345
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  18  drive_count :  105
# 18
# epoch     :   18
# count     :   22
#   i       :   0
# Time to i :  7.619987487792969
# D_loss :  1.4075368642807007
# D_loss_real :  0.0001503490493632853
# D_loss_wrong :  0.05898667126893997
# D_loss_fake :  2.0815863609313965
# G_loss :  20.990964889526367
# KL_loss :  0.1004386767745018
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   23
#   i       :   500
# Time to i :  626.8014471530914
# D_loss :  0.43009886145591736
# D_loss_real :  0.40353959798812866
# D_loss_wrong :  0.0006073827389627695
# D_loss_fake :  0.039535198360681534
# G_loss :  2.9061803817749023
# KL_loss :  0.0925055742263794
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   24
#   i       :   1000
# Time to i :  624.0411410331726
# D_loss :  0.01988685503602028
# D_loss_real :  0.009453737176954746
# D_loss_wrong :  0.003691946854814887
# D_loss_fake :  0.013803704641759396
# G_loss :  12.463693618774414
# KL_loss :  0.09068771451711655
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   25
#   i       :   1500
# Time to i :  624.1812703609467
# D_loss :  0.046885643154382706
# D_loss_real :  0.031631071120500565
# D_loss_wrong :  0.004284305032342672
# D_loss_fake :  0.020739704370498657
# G_loss :  10.09377384185791
# KL_loss :  0.07551148533821106
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   26
#   i       :   2000
# Time to i :  624.3009197711945
# D_loss :  0.033085234463214874
# D_loss_real :  0.006191803142428398
# D_loss_wrong :  0.006297301035374403
# D_loss_fake :  0.03719149902462959
# G_loss :  9.301072120666504
# KL_loss :  0.09762458503246307
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   27
#   i       :   2500
# Time to i :  624.1003260612488
# D_loss :  0.9460269212722778
# D_loss_real :  0.9458585381507874
# D_loss_wrong :  0.00013829048839397728
# D_loss_fake :  0.00018341091345064342
# G_loss :  10.430034637451172
# KL_loss :  0.08135329931974411
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   18
# count     :   28
#   i       :   3000
# Time to i :  624.1322393417358
# D_loss :  0.07671614736318588
# D_loss_real :  0.0605267658829689
# D_loss_wrong :  0.0010023340582847595
# D_loss_fake :  0.02378290519118309
# G_loss :  11.99262809753418
# KL_loss :  0.0837903544306755
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [18/120][3448/3449] Loss_D: 1.0184 Loss_G: 3.7159 Loss_KL: 0.1045
#                      Loss_real: 1.0164 Loss_wrong:0.0035 Loss_fake 0.0014
#                      Total Time: 4318.15sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4418.83687710762
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  19  drive_count :  140
# 19
# epoch     :   19
# count     :   29
#   i       :   0
# Time to i :  8.372789144515991
# D_loss :  0.11677423119544983
# D_loss_real :  0.0006772112683393061
# D_loss_wrong :  0.0026974743232131004
# D_loss_fake :  0.17279678583145142
# G_loss :  3.9938297271728516
# KL_loss :  0.11983272433280945
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   30
#   i       :   500
# Time to i :  629.1734163761139
# D_loss :  0.07134116441011429
# D_loss_real :  0.0023308005183935165
# D_loss_wrong :  0.046284329146146774
# D_loss_fake :  0.0803733766078949
# G_loss :  8.895158767700195
# KL_loss :  0.11209559440612793
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   31
#   i       :   1000
# Time to i :  626.0820910930634
# D_loss :  0.8306145071983337
# D_loss_real :  0.8261325359344482
# D_loss_wrong :  0.0001060929789673537
# D_loss_fake :  0.006669952999800444
# G_loss :  1.1778292655944824
# KL_loss :  0.08894819021224976
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   32
#   i       :   1500
# Time to i :  624.3698098659515
# D_loss :  0.008353973738849163
# D_loss_real :  0.004781580995768309
# D_loss_wrong :  0.0008960863924585283
# D_loss_fake :  0.004910545889288187
# G_loss :  11.837141036987305
# KL_loss :  0.08729364722967148
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   33
#   i       :   2000
# Time to i :  624.2784857749939
# D_loss :  0.10709646344184875
# D_loss_real :  0.006680912338197231
# D_loss_wrong :  0.006834163796156645
# D_loss_fake :  0.14720624685287476
# G_loss :  6.733856201171875
# KL_loss :  0.1009073257446289
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   34
#   i       :   2500
# Time to i :  624.0536091327667
# D_loss :  0.4825471341609955
# D_loss_real :  0.3628135919570923
# D_loss_wrong :  0.0001394409773638472
# D_loss_fake :  0.17953059077262878
# G_loss :  7.432380676269531
# KL_loss :  0.08337879180908203
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   19
# count     :   35
#   i       :   3000
# Time to i :  624.2528672218323
# D_loss :  3.8272576332092285
# D_loss_real :  0.000281407090369612
# D_loss_wrong :  0.009626728482544422
# D_loss_fake :  5.735650539398193
# G_loss :  4.384750843048096
# KL_loss :  0.11761723458766937
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [19/120][3448/3449] Loss_D: 0.1630 Loss_G: 4.3673 Loss_KL: 0.1177
#                      Loss_real: 0.0014 Loss_wrong:0.0002 Loss_fake 0.2422
#                      Total Time: 4323.40sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4323.404123783112
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  20  drive_count :  175
# 20
# epoch     :   20
# count     :   36
#   i       :   0
# Time to i :  7.851854085922241
# D_loss :  1.2897677421569824
# D_loss_real :  0.000980668468400836
# D_loss_wrong :  0.000614870572462678
# D_loss_fake :  1.932873249053955
# G_loss :  4.402116775512695
# KL_loss :  0.12283754348754883
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   37
#   i       :   500
# Time to i :  626.6086766719818
# D_loss :  0.03254581242799759
# D_loss_real :  0.024605095386505127
# D_loss_wrong :  0.0003573443100322038
# D_loss_fake :  0.011732404120266438
# G_loss :  9.33592414855957
# KL_loss :  0.10262162983417511
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   38
#   i       :   1000
# Time to i :  624.2734634876251
# D_loss :  0.04072941839694977
# D_loss_real :  0.038114193826913834
# D_loss_wrong :  0.0007613282068632543
# D_loss_fake :  0.0035421736538410187
# G_loss :  11.47347640991211
# KL_loss :  0.11951158940792084
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   39
#   i       :   1500
# Time to i :  624.2950868606567
# D_loss :  0.04812749847769737
# D_loss_real :  0.011427232064306736
# D_loss_wrong :  0.00312682893127203
# D_loss_fake :  0.053486984223127365
# G_loss :  7.490182399749756
# KL_loss :  0.09990906715393066
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   40
#   i       :   2000
# Time to i :  624.5723142623901
# D_loss :  0.005740726366639137
# D_loss_real :  0.00295246671885252
# D_loss_wrong :  0.0005230727838352323
# D_loss_fake :  0.003920852672308683
# G_loss :  12.638516426086426
# KL_loss :  0.10633065551519394
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   41
#   i       :   2500
# Time to i :  624.2013146877289
# D_loss :  0.003366369754076004
# D_loss_real :  0.0012785535072907805
# D_loss_wrong :  0.00040843855822458863
# D_loss_fake :  0.002927505411207676
# G_loss :  9.452118873596191
# KL_loss :  0.09555947780609131
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   20
# count     :   42
#   i       :   3000
# Time to i :  624.2486481666565
# D_loss :  0.24336211383342743
# D_loss_real :  0.22562283277511597
# D_loss_wrong :  0.001509202877059579
# D_loss_fake :  0.02585432305932045
# G_loss :  3.9704999923706055
# KL_loss :  0.10523253679275513
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# [20/120][3448/3449] Loss_D: 0.0280 Loss_G: 16.6608 Loss_KL: 0.0801
#                      Loss_real: 0.0261 Loss_wrong:0.0016 Loss_fake 0.0020
#                      Total Time: 4318.57sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4419.735767126083
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  21  drive_count :  210
# 21
# epoch     :   21
# count     :   43
#   i       :   0
# Time to i :  8.530731201171875
# D_loss :  0.08227960765361786
# D_loss_real :  0.07157986611127853
# D_loss_wrong :  0.03188189119100571
# D_loss_fake :  0.00010866674710996449
# G_loss :  19.302722930908203
# KL_loss :  0.1187388226389885
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
# epoch     :   21
# count     :   44
#   i       :   500
# Time to i :  629.1785609722137
# D_loss :  0.01814989373087883
# D_loss_real :  0.014939826913177967
# D_loss_wrong :  0.007080244831740856
# D_loss_fake :  0.0012749782763421535
# G_loss :  13.563641548156738
# KL_loss :  0.0953238308429718
# generator_lr :  0.0001
# discriminator_lr :  0.0001
# lr_decay_step :  20
