# %%
# !nvidia-smi
# Out:
# Wed May  6 21:02:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
#!rm -r sample_data

#clone repo multiple-objects-gan
# !git clone https://github.com/tohinz/multiple-objects-gan.git

#!!EDIT THE CHECKPOINT HERE AND IN CONFIG.PY AND IMPORT THE RIGHT DRIVE!!
# !cp '/content/drive/My Drive/coco2Model/checkpoint_0014.pth' '/content/multiple-objects-gan/models/'

#Clone repo COCO-Stack2-GAN
# !git clone https://github.com/ammarnasr/COCO-Stack2-GAN.git

#Move code files coco_s2_train.yml, config.py, utils.py, datasets.py, trainer.py  to their Locations
# !mv /content/COCO-Stack2-GAN/theCode/coco_s2_train.yml /content/multiple-objects-gan/code/coco/stackgan/cfg/
# !mv /content/COCO-Stack2-GAN/theCode/config.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/utils.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/datasets.py    /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/trainer.py    /content/multiple-objects-gan/code/coco/stackgan/

#Remove the Repo
# !rm -r /content/COCO-Stack2-GAN/

#Changing Working dirctory to data
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads data-ms-coco.zip (4.11M) , Extract it , and remove unnesscery files
# !wget https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# !unzip -q data-ms-coco.zip
# !rm data-ms-coco.zip

#Check Working Directory And verify complete download
print(os.getcwd())
print("Check data-ms-coco.zip (4.11M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads coco.zip (1.48G) , Extract it , remove unnesscery files and reorder data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLQXVzOENCY2E3TlU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLQXVzOENCY2E3TlU" -O coco.zip && rm -rf /tmp/cookies.txt
# !unzip -q coco.zip
# !rm -r __MACOSX/
# !rm README.md
# !rm coco.zip
# !mv coco/test/filename.txt MS-COCO/test/
# !mv coco/test/filenames.pickle MS-COCO/test/
# !mv coco/train/char-CNN-RNN-embeddings.pickle MS-COCO/train/
# !mv coco/train/filenames.pickle MS-COCO/train/
# !rm -r coco/

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/MS-COCO/train/')
print(os.getcwd())
print("Check coco.zip (1.48G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads train2014.zip (12.58G) , Extract it , and remove unnesscery files
# !wget http://images.cocodataset.org/zips/train2014.zip
# !unzip -q train2014.zip
# !rm train2014.zip

#Create & Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
os.mkdir('models')
os.chdir('/content/multiple-objects-gan/data/models/')
print(os.getcwd())
print("Check train2014.zip (12.58G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Move pretrained_model.pth (455.37M) to created directory
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU" -O pretrained_model.pth && rm -rf /tmp/cookies.txt

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/')
print(os.getcwd())
print("Check pretrained_model.pth (455.37M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")


#The Command !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Cloning into 'multiple-objects-gan'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 415 (delta 4), reused 0 (delta 0), pack-reused 398
# Receiving objects: 100% (415/415), 23.04 MiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Cloning into 'COCO-Stack2-GAN'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 102 (delta 47), reused 75 (delta 25), pack-reused 0
# Receiving objects: 100% (102/102), 1.45 MiB | 3.27 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/multiple-objects-gan/data
# Check Marker in first Comment of every file for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-06 21:06:26--  https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# Resolving www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)... 134.100.9.79
# Connecting to www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)|134.100.9.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4312414 (4.1M) [application/zip]
# Saving to: ‘data-ms-coco.zip’
#
# data-ms-coco.zip    100%[===================>]   4.11M  --.-KB/s    in 0.06s
#
# 2020-05-06 21:06:26 (65.3 MB/s) - ‘data-ms-coco.zip’ saved [4312414/4312414]
#
# /content/multiple-objects-gan/data
# Check data-ms-coco.zip (4.11M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-06 21:06:34--  https://docs.google.com/uc?export=download&confirm=vpiy&id=0B3y_msrWZaXLQXVzOENCY2E3TlU
# Resolving docs.google.com (docs.google.com)... 74.125.143.100, 74.125.143.102, 74.125.143.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.143.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download [following]
# --2020-05-06 21:06:34--  https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download
# Resolving doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)... 172.217.218.132, 2a00:1450:4013:c08::84
# Connecting to doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)|172.217.218.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=pveerto8ovdaa&continue=https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=h23evg7pk38d5h9mr7oktp1djps0j527 [following]
# --2020-05-06 21:06:34--  https://docs.google.com/nonceSigner?nonce=pveerto8ovdaa&continue=https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=h23evg7pk38d5h9mr7oktp1djps0j527
# Connecting to docs.google.com (docs.google.com)|74.125.143.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=pveerto8ovdaa&user=15434986813664770992Z&hash=ovuokn3pas15o4t3rqkb621tvksp85pk [following]
# --2020-05-06 21:06:34--  https://doc-0g-80-docs.googleusercontent.com/docs/securesc/3ie7t8af6vuq196k0tipaq6khjsjq4ut/khlgcqr8n9qcirqbvkufdaq9qttl9n7a/1588799175000/16427414401649018968/15434986813664770992Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=pveerto8ovdaa&user=15434986813664770992Z&hash=ovuokn3pas15o4t3rqkb621tvksp85pk
# Connecting to doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)|172.217.218.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘coco.zip’
#
# coco.zip                [               <=>  ]   1.48G  94.0MB/s    in 13s
#
# 2020-05-06 21:06:48 (120 MB/s) - ‘coco.zip’ saved [1587844671]
#
# /content/multiple-objects-gan/data/MS-COCO/train
# Check coco.zip (1.48G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-06 21:07:45--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.179.163
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.179.163|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  35.0MB/s    in 6m 10s
#
# 2020-05-06 21:13:55 (34.8 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# /content/multiple-objects-gan/data
# /content/multiple-objects-gan/data/models
# Check train2014.zip (12.58G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-06 21:20:38--  https://docs.google.com/uc?export=download&confirm=u_t5&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU
# Resolving docs.google.com (docs.google.com)... 74.125.143.102, 74.125.143.101, 74.125.143.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.143.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download [following]
# --2020-05-06 21:20:38--  https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download
# Resolving doc-0k-4g-docs.googleusercontent.com (doc-0k-4g-docs.googleusercontent.com)... 172.217.218.132, 2a00:1450:4013:c08::84
# Connecting to doc-0k-4g-docs.googleusercontent.com (doc-0k-4g-docs.googleusercontent.com)|172.217.218.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=n96hrv49brff6&continue=https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=am58bf635e263j1cuhcam2g7r1239pdd [following]
# --2020-05-06 21:20:39--  https://docs.google.com/nonceSigner?nonce=n96hrv49brff6&continue=https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=am58bf635e263j1cuhcam2g7r1239pdd
# Connecting to docs.google.com (docs.google.com)|74.125.143.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=n96hrv49brff6&user=15068525939763173068Z&hash=vvvvlnj7qocmf2j8tdj48kh658gs4dgl [following]
# --2020-05-06 21:20:39--  https://doc-0k-4g-docs.googleusercontent.com/docs/securesc/45404hsml0sup2k911bg239duk2rj6a9/q9f14ujjnlemluou3k4tg6t56majsrh8/1588800000000/06568122908834480149/15068525939763173068Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=n96hrv49brff6&user=15068525939763173068Z&hash=vvvvlnj7qocmf2j8tdj48kh658gs4dgl
# Connecting to doc-0k-4g-docs.googleusercontent.com (doc-0k-4g-docs.googleusercontent.com)|172.217.218.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘pretrained_model.pth’
#
# pretrained_model.pt     [                <=> ] 455.37M   101MB/s    in 4.7s
#
# 2020-05-06 21:20:44 (96.0 MB/s) - ‘pretrained_model.pth’ saved [477486037]
#
# /content/multiple-objects-gan
# Check pretrained_model.pth (455.37M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------

# %%
# !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Starting training on the MS-COCO data set.
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../../../data/MS-COCO',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMG_DIR': '../../../data/MS-COCO/train/train2014',
#  'IMSIZE': 256,
#  'NET_D': '../../../models/checkpoint_0008.pth',
#  'NET_G': '../../../models/checkpoint_0008.pth',
#  'STAGE': 2,
#  'STAGE1_G': '../../../data/models/pretrained_model.pth',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 20,
#            'MAX_EPOCH': 120,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 2},
#  'USE_BBOX_LAYOUT': True,
#  'USE_LOCAL_PATHWAY': True,
#  'VIS_COUNT': 64,
#  'WORKERS': 16,
#  'Z_DIM': 100}
# Load filenames from: ../../../data/MS-COCO/train/filenames.pickle (82783)
# tcmalloc: large alloc 1695399936 bytes == 0xf92c4000 @  0x7fae4e8d51e7 0x7fae030e05e1 0x7fae03143138 0x7fae03146278 0x7fae03146855 0x7fae031ddb1d 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fae4e4d2b97 0x5b250a
# 2020-05-06 21:38:53.797191: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (bbox_net): BBOX_NET(
#       (encode): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=292, out_features=24576, bias=False)
#       (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (label): Sequential(
#       (0): Linear(in_features=209, out_features=128, bias=False)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (local1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (local2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (img): Sequential(
#       (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (label): Sequential(
#     (0): Linear(in_features=209, out_features=128, bias=False)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (local1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(896, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (local2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (encoder): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#   )
#   (hr_joint): Sequential(
#     (0): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(48, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# ---------------------------------------------------------------------------------
# Current Working Directory :  /content/multiple-objects-gan/code/coco/stackgan
# cfg.NET_G :  ../../../models/checkpoint_0008.pth
# ---------------------------------------------------------------------------------
# THIS THE CURRENT DIRECTORY :  /content/multiple-objects-gan/code/coco/stackgan
# Load from:  ../../../models/checkpoint_0008.pth
# Load from:  ../../../models/checkpoint_0008.pth
# STAGE2_D(
#   (local): Sequential(
#     (0): Conv2d(84, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(192, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (act): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv1): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(576, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(768, 1536, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(1536, 3072, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn6): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(3072, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn7): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn8): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
#   (get_uncond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
# )
# 8
# Load Optim and optimizers as :  ../../../models/checkpoint_0008.pth
# epoch :  9  drive_count :  0
# 9
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# epoch     :   9
# count     :   1
#   i       :   0
# Time to i :  16.352266788482666
# D_loss :  0.3005262613296509
# D_loss_real :  0.26523324847221375
# D_loss_wrong :  0.004408647306263447
# D_loss_fake :  0.050735194236040115
# G_loss :  2.8590517044067383
# KL_loss :  0.05272717401385307
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   2
#   i       :   500
# Time to i :  625.5821578502655
# D_loss :  0.21131359040737152
# D_loss_real :  0.08161397278308868
# D_loss_wrong :  0.00701498007401824
# D_loss_fake :  0.19104191660881042
# G_loss :  4.979499340057373
# KL_loss :  0.06563858687877655
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   3
#   i       :   1000
# Time to i :  624.5917780399323
# D_loss :  0.3530865013599396
# D_loss_real :  0.3466974198818207
# D_loss_wrong :  0.0021199246402829885
# D_loss_fake :  0.00852364581078291
# G_loss :  6.479184627532959
# KL_loss :  0.06959483027458191
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   4
#   i       :   1500
# Time to i :  624.6133320331573
# D_loss :  0.09190718829631805
# D_loss_real :  0.03881487250328064
# D_loss_wrong :  0.05010026693344116
# D_loss_fake :  0.05458833649754524
# G_loss :  5.533491134643555
# KL_loss :  0.08993791043758392
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   5
#   i       :   2000
# Time to i :  624.5893092155457
# D_loss :  0.11861616373062134
# D_loss_real :  0.0545588918030262
# D_loss_wrong :  0.0020084655843675137
# D_loss_fake :  0.09508167207241058
# G_loss :  4.544524669647217
# KL_loss :  0.07244860380887985
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   6
#   i       :   2500
# Time to i :  624.4679689407349
# D_loss :  0.4879010319709778
# D_loss_real :  0.4768115282058716
# D_loss_wrong :  0.0053312345407903194
# D_loss_fake :  0.013968633487820625
# G_loss :  7.34450626373291
# KL_loss :  0.04814803600311279
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   9
# count     :   7
#   i       :   3000
# Time to i :  624.2818715572357
# D_loss :  0.7894816398620605
# D_loss_real :  0.7760655879974365
# D_loss_wrong :  0.0009035776020027697
# D_loss_fake :  0.019672313705086708
# G_loss :  2.469545602798462
# KL_loss :  0.06865230202674866
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [9/120][3448/3449] Loss_D: 0.4722 Loss_G: 4.2352 Loss_KL: 0.0582
#                      Loss_real: 0.3257 Loss_wrong:0.0010 Loss_fake 0.2192
#                      Total Time: 4326.86sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4326.864335775375
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  10  drive_count :  35
# 10
# epoch     :   10
# count     :   8
#   i       :   0
# Time to i :  6.246592283248901
# D_loss :  0.37961721420288086
# D_loss_real :  0.044115349650382996
# D_loss_wrong :  0.002178814494982362
# D_loss_fake :  0.5021633505821228
# G_loss :  9.216804504394531
# KL_loss :  0.059747256338596344
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   9
#   i       :   500
# Time to i :  626.6763095855713
# D_loss :  0.22209084033966064
# D_loss_real :  0.10246728360652924
# D_loss_wrong :  0.002950885333120823
# D_loss_fake :  0.1779598891735077
# G_loss :  4.2827606201171875
# KL_loss :  0.06984420120716095
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   10
#   i       :   1000
# Time to i :  624.2060573101044
# D_loss :  1.0686705112457275
# D_loss_real :  0.0017743008211255074
# D_loss_wrong :  0.02391272597014904
# D_loss_fake :  1.5883878469467163
# G_loss :  10.066274642944336
# KL_loss :  0.06539496779441833
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   11
#   i       :   1500
# Time to i :  624.4243865013123
# D_loss :  0.2817865312099457
# D_loss_real :  0.03647742420434952
# D_loss_wrong :  0.04937441647052765
# D_loss_fake :  0.3432764410972595
# G_loss :  9.404605865478516
# KL_loss :  0.06308858841657639
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   12
#   i       :   2000
# Time to i :  624.1817135810852
# D_loss :  0.5281591415405273
# D_loss_real :  0.048194825649261475
# D_loss_wrong :  0.008022760972380638
# D_loss_fake :  0.7159351110458374
# G_loss :  11.47701358795166
# KL_loss :  0.06902380287647247
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   13
#   i       :   2500
# Time to i :  624.1528105735779
# D_loss :  0.1447654664516449
# D_loss_real :  0.03978317603468895
# D_loss_wrong :  0.003003909019753337
# D_loss_fake :  0.1559714674949646
# G_loss :  8.970706939697266
# KL_loss :  0.08626538515090942
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   10
# count     :   14
#   i       :   3000
# Time to i :  623.795964717865
# D_loss :  2.438685655593872
# D_loss_real :  2.436824321746826
# D_loss_wrong :  0.003199951257556677
# D_loss_fake :  0.0011922012781724334
# G_loss :  5.181578159332275
# KL_loss :  0.07357414811849594
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [10/120][3448/3449] Loss_D: 0.4073 Loss_G: 6.4307 Loss_KL: 0.0573
#                      Loss_real: 0.3771 Loss_wrong:0.0003 Loss_fake 0.0451
#                      Total Time: 4315.42sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4416.014099597931
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  11  drive_count :  70
# 11
# epoch     :   11
# count     :   15
#   i       :   0
# Time to i :  6.290975332260132
# D_loss :  0.6865650415420532
# D_loss_real :  0.6737716794013977
# D_loss_wrong :  0.0006085363565944135
# D_loss_fake :  0.018885765224695206
# G_loss :  0.920484185218811
# KL_loss :  0.08108453452587128
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   16
#   i       :   500
# Time to i :  627.8121140003204
# D_loss :  0.13615232706069946
# D_loss_real :  0.01650688797235489
# D_loss_wrong :  0.00197608326561749
# D_loss_fake :  0.1784800887107849
# G_loss :  6.687295436859131
# KL_loss :  0.07962130010128021
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   17
#   i       :   1000
# Time to i :  623.9078960418701
# D_loss :  0.7313994765281677
# D_loss_real :  0.28054845333099365
# D_loss_wrong :  0.00034938458702526987
# D_loss_fake :  0.676101803779602
# G_loss :  9.65446949005127
# KL_loss :  0.0682392343878746
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   18
#   i       :   1500
# Time to i :  623.7659978866577
# D_loss :  0.4140026569366455
# D_loss_real :  0.036135949194431305
# D_loss_wrong :  0.05097051337361336
# D_loss_fake :  0.5413148403167725
# G_loss :  9.30168342590332
# KL_loss :  0.08003903925418854
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   19
#   i       :   2000
# Time to i :  623.8499615192413
# D_loss :  0.10836804658174515
# D_loss_real :  0.0024459806736558676
# D_loss_wrong :  0.003157200524583459
# D_loss_fake :  0.15730449557304382
# G_loss :  10.297776222229004
# KL_loss :  0.07222112268209457
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   20
#   i       :   2500
# Time to i :  623.609138250351
# D_loss :  0.20249474048614502
# D_loss_real :  0.107578806579113
# D_loss_wrong :  0.007770930882543325
# D_loss_fake :  0.13848842680454254
# G_loss :  6.930177688598633
# KL_loss :  0.07945709675550461
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   11
# count     :   21
#   i       :   3000
# Time to i :  623.8614466190338
# D_loss :  0.0822305977344513
# D_loss_real :  0.04185488820075989
# D_loss_wrong :  0.018810288980603218
# D_loss_fake :  0.05115841329097748
# G_loss :  7.304161071777344
# KL_loss :  0.07973625510931015
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [11/120][3448/3449] Loss_D: 0.2111 Loss_G: 8.6967 Loss_KL: 0.0743
#                      Loss_real: 0.0041 Loss_wrong:0.0328 Loss_fake 0.2941
#                      Total Time: 4314.97sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4314.9730105400085
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  12  drive_count :  105
# 12
# epoch     :   12
# count     :   22
#   i       :   0
# Time to i :  5.930521726608276
# D_loss :  0.6841230392456055
# D_loss_real :  0.5987368822097778
# D_loss_wrong :  0.002383891027420759
# D_loss_fake :  0.12688730657100677
# G_loss :  4.3757548332214355
# KL_loss :  0.07779058068990707
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   23
#   i       :   500
# Time to i :  625.9463591575623
# D_loss :  0.21462836861610413
# D_loss_real :  0.04001091048121452
# D_loss_wrong :  0.017232317477464676
# D_loss_fake :  0.25331002473831177
# G_loss :  13.209579467773438
# KL_loss :  0.07921350002288818
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   24
#   i       :   1000
# Time to i :  623.763081073761
# D_loss :  2.342662811279297
# D_loss_real :  0.0004410332185216248
# D_loss_wrong :  0.2872805893421173
# D_loss_fake :  3.369692087173462
# G_loss :  17.35767364501953
# KL_loss :  0.10715983808040619
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   25
#   i       :   1500
# Time to i :  623.7790365219116
# D_loss :  0.5992770791053772
# D_loss_real :  0.5980583429336548
# D_loss_wrong :  0.002722115721553564
# D_loss_fake :  0.0004670053895097226
# G_loss :  10.097566604614258
# KL_loss :  0.0911000669002533
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   26
#   i       :   2000
# Time to i :  623.6781194210052
# D_loss :  0.6089785099029541
# D_loss_real :  0.13293954730033875
# D_loss_wrong :  0.01675630733370781
# D_loss_fake :  0.705680251121521
# G_loss :  14.997626304626465
# KL_loss :  0.078566774725914
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   27
#   i       :   2500
# Time to i :  623.5876042842865
# D_loss :  1.9054316282272339
# D_loss_real :  0.001719553954899311
# D_loss_wrong :  0.03952600061893463
# D_loss_fake :  2.8358049392700195
# G_loss :  5.3681960105896
# KL_loss :  0.08074016869068146
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   12
# count     :   28
#   i       :   3000
# Time to i :  623.8796381950378
# D_loss :  0.09642241895198822
# D_loss_real :  0.05710510164499283
# D_loss_wrong :  0.002853075275197625
# D_loss_fake :  0.05754943937063217
# G_loss :  5.556668758392334
# KL_loss :  0.08915623277425766
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [12/120][3448/3449] Loss_D: 0.2217 Loss_G: 5.9537 Loss_KL: 0.0754
#                      Loss_real: 0.1809 Loss_wrong:0.0003 Loss_fake 0.0611
#                      Total Time: 4313.33sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4414.824372053146
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  13  drive_count :  140
# 13
# epoch     :   13
# count     :   29
#   i       :   0
# Time to i :  6.604747295379639
# D_loss :  0.050507985055446625
# D_loss_real :  0.043819643557071686
# D_loss_wrong :  0.003305236343294382
# D_loss_fake :  0.008379891514778137
# G_loss :  9.220985412597656
# KL_loss :  0.08526575565338135
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   30
#   i       :   500
# Time to i :  629.1013729572296
# D_loss :  0.04767053201794624
# D_loss_real :  0.047204479575157166
# D_loss_wrong :  0.0006963342893868685
# D_loss_fake :  0.00035091376048512757
# G_loss :  20.13417625427246
# KL_loss :  0.06863671541213989
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   31
#   i       :   1000
# Time to i :  625.8934738636017
# D_loss :  0.35231390595436096
# D_loss_real :  0.05073501914739609
# D_loss_wrong :  0.02984788455069065
# D_loss_fake :  0.4374443590641022
# G_loss :  8.845406532287598
# KL_loss :  0.07845073938369751
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   32
#   i       :   1500
# Time to i :  624.1583955287933
# D_loss :  0.32020047307014465
# D_loss_real :  0.22056794166564941
# D_loss_wrong :  0.001094478415325284
# D_loss_fake :  0.1489015519618988
# G_loss :  6.272477149963379
# KL_loss :  0.08346360921859741
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   33
#   i       :   2000
# Time to i :  624.0750603675842
# D_loss :  0.6551201343536377
# D_loss_real :  0.004504919983446598
# D_loss_wrong :  1.6562312841415405
# D_loss_fake :  0.14780719578266144
# G_loss :  8.64806842803955
# KL_loss :  0.0908016711473465
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   34
#   i       :   2500
# Time to i :  623.9779999256134
# D_loss :  1.161815881729126
# D_loss_real :  1.1542102098464966
# D_loss_wrong :  0.0012872506631538272
# D_loss_fake :  0.010764935053884983
# G_loss :  1.8008092641830444
# KL_loss :  0.07288527488708496
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   13
# count     :   35
#   i       :   3000
# Time to i :  624.1950080394745
# D_loss :  0.2038332223892212
# D_loss_real :  0.15883687138557434
# D_loss_wrong :  0.01428823173046112
# D_loss_fake :  0.06035039573907852
# G_loss :  5.902749061584473
# KL_loss :  0.07928535342216492
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [13/120][3448/3449] Loss_D: 0.7674 Loss_G: 3.3858 Loss_KL: 0.0829
#                      Loss_real: 0.7576 Loss_wrong:0.0006 Loss_fake 0.0144
#                      Total Time: 4320.30sec
#
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4320.3049919605255
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  14  drive_count :  175
# 14
# epoch     :   14
# count     :   36
#   i       :   0
# Time to i :  6.107910394668579
# D_loss :  0.5599709153175354
# D_loss_real :  0.41910815238952637
# D_loss_wrong :  0.0010395882418379188
# D_loss_fake :  0.21077436208724976
# G_loss :  1.979809045791626
# KL_loss :  0.09657652676105499
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   37
#   i       :   500
# Time to i :  626.3337564468384
# D_loss :  0.032757967710494995
# D_loss_real :  0.0019272002391517162
# D_loss_wrong :  0.06219543516635895
# D_loss_fake :  0.015148432925343513
# G_loss :  11.48994255065918
# KL_loss :  0.09343119710683823
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   38
#   i       :   1000
# Time to i :  623.9381041526794
# D_loss :  0.015634499490261078
# D_loss_real :  0.011462055146694183
# D_loss_wrong :  0.004012069199234247
# D_loss_fake :  0.004252632148563862
# G_loss :  12.944070816040039
# KL_loss :  0.0943409651517868
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   39
#   i       :   1500
# Time to i :  624.2142660617828
# D_loss :  0.15238302946090698
# D_loss_real :  0.09043602645397186
# D_loss_wrong :  0.0010598740773275495
# D_loss_fake :  0.09239058196544647
# G_loss :  6.940370559692383
# KL_loss :  0.10974669456481934
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   40
#   i       :   2000
# Time to i :  624.5576243400574
# D_loss :  0.24492916464805603
# D_loss_real :  0.2032633125782013
# D_loss_wrong :  0.017898069694638252
# D_loss_fake :  0.053549736738204956
# G_loss :  6.802312850952148
# KL_loss :  0.08633391559123993
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   41
#   i       :   2500
# Time to i :  624.1267125606537
# D_loss :  2.9017655849456787
# D_loss_real :  2.9014532566070557
# D_loss_wrong :  0.0006086831563152373
# D_loss_fake :  0.00016398372827097774
# G_loss :  2.412814140319824
# KL_loss :  0.0877375453710556
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   14
# count     :   42
#   i       :   3000
# Time to i :  624.463525056839
# D_loss :  0.1950692981481552
# D_loss_real :  0.12715031206607819
# D_loss_wrong :  0.00945791881531477
# D_loss_fake :  0.09714951366186142
# G_loss :  6.673877716064453
# KL_loss :  0.0760551318526268
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [14/120][3448/3449] Loss_D: 0.1952 Loss_G: 9.3519 Loss_KL: 0.1076
#                      Loss_real: 0.0313 Loss_wrong:0.0001 Loss_fake 0.2458
#                      Total Time: 4316.30sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4417.827233791351
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  15  drive_count :  210
# 15
# epoch     :   15
# count     :   43
#   i       :   0
# Time to i :  6.69943380355835
# D_loss :  0.8167271614074707
# D_loss_real :  0.009248010814189911
# D_loss_wrong :  0.006748049985617399
# D_loss_fake :  1.2078447341918945
# G_loss :  21.267284393310547
# KL_loss :  0.0953807681798935
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   44
#   i       :   500
# Time to i :  628.4122090339661
# D_loss :  0.1309434175491333
# D_loss_real :  0.000388449989259243
# D_loss_wrong :  0.10548260062932968
# D_loss_fake :  0.14309115707874298
# G_loss :  3.2006561756134033
# KL_loss :  0.0831592008471489
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   45
#   i       :   1000
# Time to i :  625.8931701183319
# D_loss :  0.2782222032546997
# D_loss_real :  0.04623474180698395
# D_loss_wrong :  0.00022383249597623944
# D_loss_fake :  0.34786927700042725
# G_loss :  8.974920272827148
# KL_loss :  0.09084570407867432
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   15
# count     :   46
#   i       :   1500
# Time to i :  624.2694892883301
# D_loss :  0.14228305220603943
# D_loss_real :  0.12879788875579834
# D_loss_wrong :  0.00022303746663965285
# D_loss_fake :  0.02011622115969658
# G_loss :  9.064985275268555
# KL_loss :  0.07560229301452637
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
