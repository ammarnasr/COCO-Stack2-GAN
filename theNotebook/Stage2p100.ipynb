# %%
# !nvidia-smi
# Out:
# Mon May  4 21:47:08 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
#!rm -r sample_data

#clone repo multiple-objects-gan
# !git clone https://github.com/tohinz/multiple-objects-gan.git

#Clone repo COCO-Stack2-GAN
# !git clone https://github.com/ammarnasr/COCO-Stack2-GAN.git

#Move code files coco_s2_train.yml, config.py, utils.py, datasets.py, trainer.py  to their Locations
# !mv /content/COCO-Stack2-GAN/theCode/coco_s2_train.yml /content/multiple-objects-gan/code/coco/stackgan/cfg/
# !mv /content/COCO-Stack2-GAN/theCode/config.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/utils.py        /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/datasets.py    /content/multiple-objects-gan/code/coco/stackgan/miscc/
# !mv /content/COCO-Stack2-GAN/theCode/trainer.py    /content/multiple-objects-gan/code/coco/stackgan/

#Remove the Repo
# !rm -r /content/COCO-Stack2-GAN/

#Changing Working dirctory to data
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
print("Check Marker in first Comment of every file for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads data-ms-coco.zip (4.11M) , Extract it , and remove unnesscery files
# !wget https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# !unzip -q data-ms-coco.zip
# !rm data-ms-coco.zip

#Check Working Directory And verify complete download
print(os.getcwd())
print("Check data-ms-coco.zip (4.11M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads coco.zip (1.48G) , Extract it , remove unnesscery files and reorder data
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=0B3y_msrWZaXLQXVzOENCY2E3TlU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=0B3y_msrWZaXLQXVzOENCY2E3TlU" -O coco.zip && rm -rf /tmp/cookies.txt
# !unzip -q coco.zip
# !rm -r __MACOSX/
# !rm README.md
# !rm coco.zip
# !mv coco/test/filename.txt MS-COCO/test/
# !mv coco/test/filenames.pickle MS-COCO/test/
# !mv coco/train/char-CNN-RNN-embeddings.pickle MS-COCO/train/
# !mv coco/train/filenames.pickle MS-COCO/train/
# !rm -r coco/

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/MS-COCO/train/')
print(os.getcwd())
print("Check coco.zip (1.48G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Downloads train2014.zip (12.58G) , Extract it , and remove unnesscery files
# !wget http://images.cocodataset.org/zips/train2014.zip
# !unzip -q train2014.zip
# !rm train2014.zip

#Create & Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/data/')
print(os.getcwd())
os.mkdir('models')
os.chdir('/content/multiple-objects-gan/data/models/')
print(os.getcwd())
print("Check train2014.zip (12.58G) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

#Move pretrained_model.pth (455.37M) to created directory
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU" -O pretrained_model.pth && rm -rf /tmp/cookies.txt

#Change Working Directory And verify complete download
os.chdir('/content/multiple-objects-gan/')
print(os.getcwd())
print("Check pretrained_model.pth (455.37M) for Sucess!")
print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")


#The Command !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Cloning into 'multiple-objects-gan'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 415 (delta 4), reused 0 (delta 0), pack-reused 398
# Receiving objects: 100% (415/415), 23.04 MiB | 8.41 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Cloning into 'COCO-Stack2-GAN'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 8), reused 29 (delta 7), pack-reused 0
# Unpacking objects: 100% (36/36), done.
# /content/multiple-objects-gan/data
# Check Marker in first Comment of every file for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-04 22:00:35--  https://www2.informatik.uni-hamburg.de/wtm/software/multiple-objects-gan/data-ms-coco.zip
# Resolving www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)... 134.100.9.79
# Connecting to www2.informatik.uni-hamburg.de (www2.informatik.uni-hamburg.de)|134.100.9.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4312414 (4.1M) [application/zip]
# Saving to: ‘data-ms-coco.zip’
#
# data-ms-coco.zip    100%[===================>]   4.11M  1.85MB/s    in 2.2s
#
# 2020-05-04 22:00:39 (1.85 MB/s) - ‘data-ms-coco.zip’ saved [4312414/4312414]
#
# /content/multiple-objects-gan/data
# Check data-ms-coco.zip (4.11M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-04 22:00:46--  https://docs.google.com/uc?export=download&confirm=4ZcL&id=0B3y_msrWZaXLQXVzOENCY2E3TlU
# Resolving docs.google.com (docs.google.com)... 64.233.189.102, 64.233.189.138, 64.233.189.100, ...
# Connecting to docs.google.com (docs.google.com)|64.233.189.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download [following]
# --2020-05-04 22:00:46--  https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download
# Resolving doc-0g-60-docs.googleusercontent.com (doc-0g-60-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-0g-60-docs.googleusercontent.com (doc-0g-60-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=8ikgac94qg7vg&continue=https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=hs5rgrjjqr7541anm56hv522ttea1sh3 [following]
# --2020-05-04 22:00:46--  https://docs.google.com/nonceSigner?nonce=8ikgac94qg7vg&continue=https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e%3Ddownload&hash=hs5rgrjjqr7541anm56hv522ttea1sh3
# Connecting to docs.google.com (docs.google.com)|64.233.189.102|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=8ikgac94qg7vg&user=17380289106533793140Z&hash=m1sbtlfg7i9ac3l6ti6nhnjcld1r46dd [following]
# --2020-05-04 22:00:47--  https://doc-0g-60-docs.googleusercontent.com/docs/securesc/9j07gilhpp86ktvpg3r8adv241h1vo61/fmjqo34atuf13s7eqrm1fef75bqrf0dq/1588629600000/16427414401649018968/17380289106533793140Z/0B3y_msrWZaXLQXVzOENCY2E3TlU?e=download&nonce=8ikgac94qg7vg&user=17380289106533793140Z&hash=m1sbtlfg7i9ac3l6ti6nhnjcld1r46dd
# Connecting to doc-0g-60-docs.googleusercontent.com (doc-0g-60-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘coco.zip’
#
# coco.zip                [       <=>          ]   1.48G   141MB/s    in 8.4s
#
# 2020-05-04 22:00:56 (181 MB/s) - ‘coco.zip’ saved [1587844671]
#
# /content/multiple-objects-gan/data/MS-COCO/train
# Check coco.zip (1.48G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-04 22:01:55--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.177.123
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.177.123|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  16.7MB/s    in 13m 16s
#
# 2020-05-04 22:15:12 (16.2 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# /content/multiple-objects-gan/data
# /content/multiple-objects-gan/data/models
# Check train2014.zip (12.58G) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# --2020-05-04 22:21:45--  https://docs.google.com/uc?export=download&confirm=Xfdm&id=1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU
# Resolving docs.google.com (docs.google.com)... 108.177.125.100, 108.177.125.101, 108.177.125.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.125.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download [following]
# --2020-05-04 22:21:46--  https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download
# Resolving doc-14-8k-docs.googleusercontent.com (doc-14-8k-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-14-8k-docs.googleusercontent.com (doc-14-8k-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=nlqkvnmemc0js&continue=https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=r3mdqut10369jk3ng4p12v3v676jtgd5 [following]
# --2020-05-04 22:21:46--  https://docs.google.com/nonceSigner?nonce=nlqkvnmemc0js&continue=https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e%3Ddownload&hash=r3mdqut10369jk3ng4p12v3v676jtgd5
# Connecting to docs.google.com (docs.google.com)|108.177.125.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=nlqkvnmemc0js&user=10949065466644183022Z&hash=kktqkvtpf2emc3vdooohapgi9ad61per [following]
# --2020-05-04 22:21:48--  https://doc-14-8k-docs.googleusercontent.com/docs/securesc/nv4rjkq9rpip4870slhea6grbq8ui49j/ea5bol5jbhr555e9i4ep174vvfq5cmjk/1588630875000/06568122908834480149/10949065466644183022Z/1XlBL5ZvK-SosZsx8WWcHddmBnHm8TpAU?e=download&nonce=nlqkvnmemc0js&user=10949065466644183022Z&hash=kktqkvtpf2emc3vdooohapgi9ad61per
# Connecting to doc-14-8k-docs.googleusercontent.com (doc-14-8k-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘pretrained_model.pth’
#
# pretrained_model.pt     [         <=>        ] 455.37M  48.8MB/s    in 9.8s
#
# 2020-05-04 22:21:58 (46.5 MB/s) - ‘pretrained_model.pth’ saved [477486037]
#
# /content/multiple-objects-gan
# Check pretrained_model.pth (455.37M) for Sucess!
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------

# %%
# !sh train.sh coco-stackgan-2 '0' #12:30 am , 2/1/2020 epoch 14 at 3:20 am
# Out:
# Starting training on the MS-COCO data set.
# Using config:
# {'CONFIG_NAME': 'stageII',
#  'CUDA': True,
#  'DATASET_NAME': 'coco',
#  'DATA_DIR': '../../../data/MS-COCO',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'CONDITION_DIM': 128, 'DF_DIM': 96, 'GF_DIM': 192, 'R_NUM': 2},
#  'GPU_ID': '0',
#  'IMG_DIR': '../../../data/MS-COCO/train/train2014',
#  'IMSIZE': 256,
#  'NET_D': '',
#  'NET_G': '',
#  'STAGE': 2,
#  'STAGE1_G': '../../../data/models/pretrained_model.pth',
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'KL': 2.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'LR_DECAY_EPOCH': 20,
#            'MAX_EPOCH': 120,
#            'PRETRAINED_EPOCH': 600,
#            'PRETRAINED_MODEL': '',
#            'SNAPSHOT_INTERVAL': 2},
#  'USE_BBOX_LAYOUT': True,
#  'USE_LOCAL_PATHWAY': True,
#  'VIS_COUNT': 64,
#  'WORKERS': 16,
#  'Z_DIM': 100}
# Load filenames from: ../../../data/MS-COCO/train/filenames.pickle (82783)
# tcmalloc: large alloc 1695399936 bytes == 0xf98ee000 @  0x7fda135261e7 0x7fd9c7d315e1 0x7fd9c7d94138 0x7fd9c7d97278 0x7fd9c7d97855 0x7fd9c7e2eb1d 0x50ac25 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7fda13123b97 0x5b2fda
# 2020-05-04 22:23:52.599535: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# STAGE2_G(
#   (STAGE1_G): STAGE1_G(
#     (ca_net): CA_NET(
#       (fc): Linear(in_features=1024, out_features=256, bias=True)
#       (relu): ReLU()
#     )
#     (bbox_net): BBOX_NET(
#       (encode): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): LeakyReLU(negative_slope=0.2, inplace=True)
#         (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): LeakyReLU(negative_slope=0.2, inplace=True)
#         (5): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=292, out_features=24576, bias=False)
#       (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (label): Sequential(
#       (0): Linear(in_features=209, out_features=128, bias=False)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (local1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (local2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(768, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (upsample4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (img): Sequential(
#       (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (label): Sequential(
#     (0): Linear(in_features=209, out_features=128, bias=False)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (local1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(896, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (local2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (encoder): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#   )
#   (hr_joint): Sequential(
#     (0): Conv2d(1024, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(48, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# Load from:  ../../../data/models/pretrained_model.pth
# STAGE2_D(
#   (local): Sequential(
#     (0): Conv2d(84, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(192, 192, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (act): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv1): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(576, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(768, 1536, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn5): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(1536, 3072, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn6): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(3072, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn7): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn8): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
#   (get_uncond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#     )
#   )
# )
# epoch :  0  drive_count :  0
# 0
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3289: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# epoch     :   0
# count     :   1
#   i       :   0
# Time to i :  16.45279097557068
# D_loss :  1.7366104125976562
# D_loss_real :  1.1582481861114502
# D_loss_wrong :  0.5961125493049622
# D_loss_fake :  0.5694870948791504
# G_loss :  11.228943824768066
# KL_loss :  0.0037643220275640488
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   2
#   i       :   500
# Time to i :  625.9376831054688
# D_loss :  1.2481226921081543
# D_loss_real :  0.5435745716094971
# D_loss_wrong :  0.5860497355461121
# D_loss_fake :  0.7637971639633179
# G_loss :  1.6397593021392822
# KL_loss :  0.002858794992789626
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   3
#   i       :   1000
# Time to i :  626.4288687705994
# D_loss :  1.0289164781570435
# D_loss_real :  0.47548726201057434
# D_loss_wrong :  0.48367753624916077
# D_loss_fake :  0.5883051156997681
# G_loss :  4.20348596572876
# KL_loss :  0.010334942489862442
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   4
#   i       :   1500
# Time to i :  626.5701537132263
# D_loss :  1.3502585887908936
# D_loss_real :  0.8922362327575684
# D_loss_wrong :  0.12157668173313141
# D_loss_fake :  0.6262452602386475
# G_loss :  1.714548945426941
# KL_loss :  0.010179105214774609
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   5
#   i       :   2000
# Time to i :  626.2806620597839
# D_loss :  1.6297670602798462
# D_loss_real :  0.970962643623352
# D_loss_wrong :  0.11654843389987946
# D_loss_fake :  0.9299323558807373
# G_loss :  1.0781304836273193
# KL_loss :  0.019159195944666862
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   6
#   i       :   2500
# Time to i :  626.8905439376831
# D_loss :  1.1978952884674072
# D_loss_real :  0.33170560002326965
# D_loss_wrong :  0.43386194109916687
# D_loss_fake :  1.0823534727096558
# G_loss :  3.494666576385498
# KL_loss :  0.011612391099333763
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   0
# count     :   7
#   i       :   3000
# Time to i :  626.1618888378143
# D_loss :  1.1576142311096191
# D_loss_real :  0.5621869564056396
# D_loss_wrong :  0.14044849574565887
# D_loss_fake :  0.8229166269302368
# G_loss :  2.251046657562256
# KL_loss :  0.019495833665132523
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# [0/120][3448/3449] Loss_D: 1.0690 Loss_G: 2.2564 Loss_KL: 0.0202
#                      Loss_real: 0.5115 Loss_wrong:0.2864 Loss_fake 0.6932
#                      Total Time: 4339.38sec
#
# Save G/D models
# keyTime |||||||||||||||||||||||||||||||
# epoch_time :  4439.586272954941
# KeyTime |||||||||||||||||||||||||||||||
# epoch :  1  drive_count :  35
# 1
# epoch     :   1
# count     :   8
#   i       :   0
# Time to i :  7.733906269073486
# D_loss :  1.1826870441436768
# D_loss_real :  0.3185890316963196
# D_loss_wrong :  0.08430666476488113
# D_loss_fake :  1.2539935111999512
# G_loss :  3.342484712600708
# KL_loss :  0.023905478417873383
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   1
# count     :   9
#   i       :   500
# Time to i :  630.91055727005
# D_loss :  1.1126766204833984
# D_loss_real :  0.2106456309556961
# D_loss_wrong :  0.20025648176670074
# D_loss_fake :  1.2529181241989136
# G_loss :  3.307157039642334
# KL_loss :  0.018265575170516968
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   1
# count     :   10
#   i       :   1000
# Time to i :  626.0790395736694
# D_loss :  0.7409994602203369
# D_loss_real :  0.5065387487411499
# D_loss_wrong :  0.0914066880941391
# D_loss_fake :  0.305987685918808
# G_loss :  3.1798205375671387
# KL_loss :  0.039860256016254425
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   1
# count     :   11
#   i       :   1500
# Time to i :  625.7743256092072
# D_loss :  0.9286583662033081
# D_loss_real :  0.38670799136161804
# D_loss_wrong :  0.28514137864112854
# D_loss_fake :  0.6703548431396484
# G_loss :  1.9763301610946655
# KL_loss :  0.02381882816553116
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
# epoch     :   1
# count     :   12
#   i       :   2000
# Time to i :  625.6876401901245
# D_loss :  1.1568984985351562
# D_loss_real :  0.39305567741394043
# D_loss_wrong :  0.05688412860035896
# D_loss_fake :  1.1173222064971924
# G_loss :  3.1324267387390137
# KL_loss :  0.02981010638177395
# generator_lr :  0.0002
# discriminator_lr :  0.0002
# lr_decay_step :  20
